# %% [markdown]
# # Assignment 3

# %% [raw]
# WebSocialytics is a company focused on collecting customer reviews for different products manufactured by different vendors and sold by different retailers
#
# WebSocialytics is your imaginary fast-growing social media company that has a business model similar to yelp.

# %% [raw]
# Every review filled out by the customer online and collected and maintained by Socialytics has the  fields listed below(though customers might submit messy reviews, inaccurate review, and yet faked (spam) reviews are real challenge as well.
#
# However, for the purpose of this assignment assume we have the following fields for the review form that is filled out by the customer online:

# %% [markdown]
# ### The Potential of Reviews Analytics

# %% [raw]
# Reviews can be used by customers, retailers, and  manufacturers to create predictive models (Clustering, Associations, Classification, Sentiment Analysis, etc.) in order to support the decision making process.
#
# For example,
# - How likely a certain product will receive a bad rating in certain zip code
# - Clustering of the products based on their ratings
# - Analysis of successful marketing campaigns by retailers/manufacturers
# - Increase cross-selling by retailers
# - How likely an existing customer will buy a newly introduced product to the market
# - When customers buy the newly introduced product to the market, what other products do they tend to buy?

# %% [markdown]
# ### Data Preparation & Analysis

# %% [raw]
# The dataset of the reviews given to us is in a plain textfile.
#
# There are a number of tasks that we need to work in order to prepare and present the data in a form that could be used by a data analytics  tool or database engine.
#
# We will use Python to prepare and process the given dataset file.
#
# Steps to consider:
# 1. Inspect and Analyze the data
# 2. Process and Prepare the data
# 3. Present the data

# %% [markdown]
# ### Review Form Fields

# %% [raw]
# Product/ModelName:
# Product/Category:
# Product/Price:
# Retailer/Name:
# Retailer/ZipCode:
# Retailer/City:
# Retailer/State:
# Retailer/On Sale:
# Manufacturer/Name:
# Manufacturer/Rebate:
# Review/UserId:
# Review/Rating:
# Review/Date:
# Review/Text:

# %% [markdown]
# ### Example of Review Form Filled out

# %% [raw]
# ProductModelName: Galaxy S4
# ProductCategory: Smart Phone
# ProductPrice: 499
# RetailerName: Bestbuy
# RetailerZipCode: 44114
# RetailerCity: Cleveland
# RetailerState: OH
# RetailerOnSale: No
# ManufacturerName: Samsung
# ManufacturerRebate: No
# ReviewUserId: xmm473
# ReviewRating: 3
# ReviewDate: 6/10/2012
# ReviewText: overheats after 2 hours

# %% [markdown]
# ### Data Set File:  CustomerReviews.txt

# %% [raw]
# The dataset that we have received from Socialytics has 100 reviews filled by different customers for different products bought from different retailers and manufactured by different vendors.
#
# The data set is saved in plainntext format in the file CustomerReviews.txt which is available with this assignment.
#
# Different reviews, in the file, are separated by BLANK LINEs.

# %%
import os

import pickle

import pandas as pd  

import numpy as np  

from pandas import DataFrame, Series

# %%
# 1. Open the fiel to read it
f =  open('CustomerReviews.txt')

# 2. Read the entire file in one step as a single GIANT string
raw_giant_string_data = f.read()

# %%
# Verify the datatype you got?
type(raw_giant_string_data)
# Out:
# str

# %%
# 3. Split the GIANT string you read into LIST of lines
raw_list_of_strings_data = raw_giant_string_data.splitlines()

# %%
# Verify the datatype you got?
type(raw_list_of_strings_data)
# Out:
# list

# %%
# 4. Print the raw_list_data
# How does the data look like in the raw_list_data?
# Every Line will be represented as an item of type (String) in the resulting LIST
raw_list_of_strings_data[:10]
# Out:
# ['ProductModelName: Samsung TV 60 LED',
#  'ProductCategory: TV',
#  'ProductPrice: 1200',
#  'RetailerName: Bestbuy',
#  'RetailerZipCode: 60585',
#  'RetailerCity: Naperville',
#  'RetailerState: IL',
#  'RetailerOnSale: No',
#  'ManufacturerName: Samsung',
#  'ManufacturerRebate: No']

# %%
# Does the data list you got have similar patterns?
# Did you get a list of strings, where the PATTERN of the string could be either
#  (a) 'parameterName: parameterValue'  
#  (b)  ''     
# Note that      ''        string is the BLANK line in the textfile

# %%
# 5. Create  the LOL  - a List Of two-item Lists
# So we can have something like this:
#     [['Product/ModelName', 'Samsung TV 60 LED'],
#      ['Product/Category', 'TV'],
#      ['Product/Price', '1200'], 
#       ........................
#       ........................

# %%
# Empty list: The [] characters denote an empty list. 
# Python evaluates zero-element collections to False.
# In our data list, the blank line is represented by Empty List []

raw_list_of_lists_data = []
for row in raw_list_of_strings_data:
    if row :
        raw_list_of_lists_data = raw_list_of_lists_data +  [row.split(': ')]

# %%
type (raw_list_of_lists_data)
# Out:
# list

# %%
raw_list_of_lists_data[:32]
# Out:
# [['ProductModelName', 'Samsung TV 60 LED'],
#  ['ProductCategory', 'TV'],
#  ['ProductPrice', '1200'],
#  ['RetailerName', 'Bestbuy'],
#  ['RetailerZipCode', '60585'],
#  ['RetailerCity', 'Naperville'],
#  ['RetailerState', 'IL'],
#  ['RetailerOnSale', 'No'],
#  ['ManufacturerName', 'Samsung'],
#  ['ManufacturerRebate', 'No'],
#  ['ReviewUserId', 'abc234'],
#  ['ReviewRating', '1'],
#  ['ReviewDate', '3/14/2013'],
#  ['ReviewText', 'Bluetooth did not work for my sound system'],
#  ['ProductModelName', 'Surface 3'],
#  ['ProductCategory', 'Tablet'],
#  ['ProductPrice', '399'],
#  ['RetailerName', 'Hhgregg'],
#  ['RetailerZipCode', '90012'],
#  ['RetailerCity', 'Los Angeles'],
#  ['RetailerState', 'CA'],
#  ['RetailerOnSale', 'Yes'],
#  ['ManufacturerName', 'Microsoft'],
#  ['ManufacturerRebate', 'No'],
#  ['ReviewUserId', 'chj787'],
#  ['ReviewRating', '5'],
#  ['ReviewDate', '7/1/2014'],
#  ['ReviewText', 'Much better screen than the samsung galaxy tablet'],
#  ['ProductModelName', 'Sony TV 42 LED'],
#  ['ProductCategory', 'TV'],
#  ['ProductPrice', '800'],
#  ['RetailerName', 'Frys']]

# %%
# 6. Create a generator Method for our partitions of the reviews in the raw_list_of_lists_data

def partition_generator(reviews_list, n):
    def reviews_partitions():
        for i in range(0, len(reviews_list), n):
            yield reviews_list[i:i+n]
    return [i for i in reviews_partitions()]

# %%
partitioned_list_of_reviews = partition_generator(raw_list_of_lists_data, 14)


partitioned_list_of_reviews[:32]
# Out:
# [[['ProductModelName', 'Samsung TV 60 LED'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '1200'],
#   ['RetailerName', 'Bestbuy'],
#   ['RetailerZipCode', '60585'],
#   ['RetailerCity', 'Naperville'],
#   ['RetailerState', 'IL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'abc234'],
#   ['ReviewRating', '1'],
#   ['ReviewDate', '3/14/2013'],
#   ['ReviewText', 'Bluetooth did not work for my sound system']],
#  [['ProductModelName', 'Surface 3'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '399'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '90012'],
#   ['RetailerCity', 'Los Angeles'],
#   ['RetailerState', 'CA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Microsoft'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'chj787'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '7/1/2014'],
#   ['ReviewText', 'Much better screen than the samsung galaxy tablet']],
#  [['ProductModelName', 'Sony TV 42 LED'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '800'],
#   ['RetailerName', 'Frys'],
#   ['RetailerZipCode', '60616'],
#   ['RetailerCity', 'Chicago'],
#   ['RetailerState', 'IL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Sony'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'fdyu323'],
#   ['ReviewRating', '4'],
#   ['ReviewDate', '2/1/2013'],
#   ['ReviewText', 'Sharp screen highly recommended']],
#  [['ProductModelName', 'LG 65'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '2250'],
#   ['RetailerName', 'Bestbuy'],
#   ['RetailerZipCode', '02110'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'LG'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'spoi7124'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '5/1/2014'],
#   ['ReviewText',
#    'Exellent design and you can use the remote control to control the sound system as well']],
#  [['ProductModelName', 'Dell XP 15'],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1349'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '60616'],
#   ['RetailerCity', 'Chicago'],
#   ['RetailerState', 'IL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Dell'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'hgjhg652'],
#   ['ReviewRating', '3'],
#   ['ReviewDate', '1/14/2014'],
#   ['ReviewText', 'noisy fan']],
#  [['ProductModelName', 'HP Pavilion 15.6'],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1399'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '60603'],
#   ['RetailerCity', 'Chicago'],
#   ['RetailerState', 'IL'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'HP'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'lkju763'],
#   ['ReviewRating', '2'],
#   ['ReviewDate', '1/15/2012'],
#   ['ReviewText', 'Bad monitor']],
#  [['ProductModelName', 'Samsung TV 65 Curved'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '2199'],
#   ['RetailerName', 'Bestbuy'],
#   ['RetailerZipCode', '94102'],
#   ['RetailerCity', 'San Francisco'],
#   ['RetailerState', 'CA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'vwil639'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '8/21/2014'],
#   ['ReviewText', 'Perfect for watching basketball game']],
#  [['ProductModelName', 'HP Pavilion 15.6 '],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '599'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '33130'],
#   ['RetailerCity', 'Miami'],
#   ['RetailerState', 'FL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'HP'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'jjer917'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '10/8/2014'],
#   ['ReviewText', 'good quality and performance']],
#  [['ProductModelName', 'Galaxy S4'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '499'],
#   ['RetailerName', 'Bestbuy'],
#   ['RetailerZipCode', '44114'],
#   ['RetailerCity', 'Cleveland'],
#   ['RetailerState', 'OH'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'xmm473'],
#   ['ReviewRating', '3'],
#   ['ReviewDate', '6/10/2012'],
#   ['ReviewText', 'overheats after 2 hours']],
#  [['ProductModelName', 'Dell XP 13'],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1349'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '60616'],
#   ['RetailerCity', 'Chicago'],
#   ['RetailerState', 'IL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Dell'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'wywe5432'],
#   ['ReviewRating', '1'],
#   ['ReviewDate', '10/14/2014'],
#   ['ReviewText',
#    'screen goes blank when I start my HD games and the touch pad does not work always']],
#  [['ProductModelName', 'iPhone 6'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '299'],
#   ['RetailerName', 'Frys'],
#   ['RetailerZipCode', '30303'],
#   ['RetailerCity', 'Atlanta'],
#   ['RetailerState', 'GA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Apple'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'akiy234'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '10/17/2014'],
#   ['ReviewText', 'Very thin design and easily fits in my pocket']],
#  [['ProductModelName', 'Samsung TV 65 Curved'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '2199'],
#   ['RetailerName', 'Bestbuy'],
#   ['RetailerZipCode', '02108'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'tfdr278'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '5/24/2014'],
#   ['ReviewText', 'Amazing screen and HD pictures on this TV']],
#  [['ProductModelName', 'HTC One'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '199'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '90033'],
#   ['RetailerCity', 'Los Angeles'],
#   ['RetailerState', 'CA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'HTC'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'aopw447'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '11/21/2013'],
#   ['ReviewText',
#    'Alot of memory and you have the choice of to purchase the 16 GB to save all of your images']],
#  [['ProductModelName', 'Surface 3'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '499'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '02109'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Microsoft'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'kjru76'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '8/1/2014'],
#   ['ReviewText', 'Better screen than Samsung Galaxy tablet']],
#  [['ProductModelName', 'Lenevo Y50 '],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1349'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '33129'],
#   ['RetailerCity', 'Miami'],
#   ['RetailerState', 'FL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Lenevo'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'tom8723'],
#   ['ReviewRating', '3'],
#   ['ReviewDate', '8/18/2012'],
#   ['ReviewText', 'over priced']],
#  [['ProductModelName', 'iPad Air'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '499'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '02109'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Apple'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'hgd987'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '4/1/2013'],
#   ['ReviewText', 'Battery is ok not bad as others complain about it']],
#  [['ProductModelName', 'Samsung Galaxy Tab 4'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '399'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '02109'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'sij392'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '2/26/2014'],
#   ['ReviewText', 'Good product for good price']],
#  [['ProductModelName', 'Dell XP 13'],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1099'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '94158'],
#   ['RetailerCity', 'San Francisco'],
#   ['RetailerState', 'CA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Dell'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'apae677'],
#   ['ReviewRating', '4'],
#   ['ReviewDate', '3/10/2015'],
#   ['ReviewText', 'good for gaming']],
#  [['ProductModelName', 'HTC One'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '299'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '30303'],
#   ['RetailerCity', 'Atlanta'],
#   ['RetailerState', 'GA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'HTC'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'kjjasd67'],
#   ['ReviewRating', '2'],
#   ['ReviewDate', '10/13/2013'],
#   ['ReviewText', 'Bad battery']],
#  [['ProductModelName', 'Samsung TV 65 Curved'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '1899'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '30134'],
#   ['RetailerCity', 'Atlanta'],
#   ['RetailerState', 'GA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'uys8219'],
#   ['ReviewRating', '1'],
#   ['ReviewDate', '9/24/2014'],
#   ['ReviewText',
#    'My sound system makes background noise when I connect it to the TV']],
#  [['ProductModelName', 'Galaxy S4'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '499'],
#   ['RetailerName', 'Bestbuy'],
#   ['RetailerZipCode', '44114'],
#   ['RetailerCity', 'Cleveland'],
#   ['RetailerState', 'OH'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'djh621'],
#   ['ReviewRating', '3'],
#   ['ReviewDate', '7/10/2013'],
#   ['ReviewText', 'overheats after 2 hours']],
#  [['ProductModelName', 'Dell XP 13'],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1200'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '60616'],
#   ['RetailerCity', 'Chicago'],
#   ['RetailerState', 'IL'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Dell'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'dur565'],
#   ['ReviewRating', '3'],
#   ['ReviewDate', '8/17/2014'],
#   ['ReviewText', ' sound is not of a good quality']],
#  [['ProductModelName', 'iPhone 6'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '399'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '30303'],
#   ['RetailerCity', 'Atlanta'],
#   ['RetailerState', 'GA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Apple'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'bhru323'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '7/23/2014'],
#   ['ReviewText', 'Awesome display']],
#  [['ProductModelName', 'Samsung TV 65 Curved'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '1900'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '02108'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'jwsy537'],
#   ['ReviewRating', '4'],
#   ['ReviewDate', '2/15/2014'],
#   ['ReviewText', 'Really good for watching HD movies']],
#  [['ProductModelName', 'HTC One'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '199'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '90033'],
#   ['RetailerCity', 'Los Angeles'],
#   ['RetailerState', 'CA'],
#   ['RetailerOnSale', 'No'],
#   ['ManufacturerName', 'HTC'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'rett891'],
#   ['ReviewRating', '1'],
#   ['ReviewDate', '6/21/2014'],
#   ['ReviewText', 'Battery dies after couple of hours of usage']],
#  [['ProductModelName', 'Surface 3'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '450'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '02109'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Microsoft'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'hsy5634'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '5/19/2014'],
#   ['ReviewText', 'really cool tablet and cheap compared to other devices']],
#  [['ProductModelName', 'Lenevo Y50 '],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1149'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '33129'],
#   ['RetailerCity', 'Miami'],
#   ['RetailerState', 'FL'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Lenevo'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'sam3987'],
#   ['ReviewRating', '2'],
#   ['ReviewDate', '8/18/2014'],
#   ['ReviewText', 'Battery lasts only for 3 hours ']],
#  [['ProductModelName', 'iPad Air'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '425'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '02109'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Apple'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'lkiw736'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '8/13/2014'],
#   ['ReviewText', 'Does add  much load when you carry it in your bag']],
#  [['ProductModelName', 'Samsung Galaxy Tab 4'],
#   ['ProductCategory', 'Tablet'],
#   ['ProductPrice', '399'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '02109'],
#   ['RetailerCity', 'Boston'],
#   ['RetailerState', 'MA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'ahwy345'],
#   ['ReviewRating', '2'],
#   ['ReviewDate', '7/16/2014'],
#   ['ReviewText', 'Some of my apps do not work on this tablet ']],
#  [['ProductModelName', 'Dell XP 13'],
#   ['ProductCategory', 'Laptop'],
#   ['ProductPrice', '1150'],
#   ['RetailerName', 'Walmart'],
#   ['RetailerZipCode', '94158'],
#   ['RetailerCity', 'San Francisco'],
#   ['RetailerState', 'CA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Dell'],
#   ['ManufacturerRebate', 'No'],
#   ['ReviewUserId', 'jak7810'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '3/10/2015'],
#   ['ReviewText',
#    'perfect for work and surfing the internet. Sharp screen and alot of horse power']],
#  [['ProductModelName', 'HTC One'],
#   ['ProductCategory', 'Smart Phone'],
#   ['ProductPrice', '199'],
#   ['RetailerName', 'Target'],
#   ['RetailerZipCode', '30303'],
#   ['RetailerCity', 'Atlanta'],
#   ['RetailerState', 'GA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'HTC'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'owy2907'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '9/13/2013'],
#   ['ReviewText', 'Good design and It is cheap compared to othe devices']],
#  [['ProductModelName', 'Samsung TV 65 Curved'],
#   ['ProductCategory', 'TV'],
#   ['ProductPrice', '1899'],
#   ['RetailerName', 'Hhgregg'],
#   ['RetailerZipCode', '30134'],
#   ['RetailerCity', 'Atlanta'],
#   ['RetailerState', 'GA'],
#   ['RetailerOnSale', 'Yes'],
#   ['ManufacturerName', 'Samsung'],
#   ['ManufacturerRebate', 'Yes'],
#   ['ReviewUserId', 'fitn4937'],
#   ['ReviewRating', '5'],
#   ['ReviewDate', '5/23/2014'],
#   ['ReviewText', 'Excellent remote control design']]]

# %%
# 7. Create Column Headers
# Read the FIRST  list ONLY in the partitioned_list_of_reviews 
# and extract from it column_headers for our review_table
# All other lists have the SAME header/pattern names

column_headers_for_reviews_table = [[row[0] for row in partitioned_list_of_reviews[0]]]

# %%
column_headers_for_reviews_table
# Out:
# [['ProductModelName',
#   'ProductCategory',
#   'ProductPrice',
#   'RetailerName',
#   'RetailerZipCode',
#   'RetailerCity',
#   'RetailerState',
#   'RetailerOnSale',
#   'ManufacturerName',
#   'ManufacturerRebate',
#   'ReviewUserId',
#   'ReviewRating',
#   'ReviewDate',
#   'ReviewText']]

# %%
# 8. Create a Row  in the table for every review 
# Though remember, every review has the pairs (parameterName, parametValue)
# We already know teh parameter NAmes in the Header we created in teh prior step
# so we will read only the SECOND COLUMN of every list because that is teh value 
# of the parameter

rows_for_reviews_table = [[col[1] for col in row] for row in partitioned_list_of_reviews]

# %%
rows_for_reviews_table
# Out:
# [['Samsung TV 60 LED',
#   'TV',
#   '1200',
#   'Bestbuy',
#   '60585',
#   'Naperville',
#   'IL',
#   'No',
#   'Samsung',
#   'No',
#   'abc234',
#   '1',
#   '3/14/2013',
#   'Bluetooth did not work for my sound system'],
#  ['Surface 3',
#   'Tablet',
#   '399',
#   'Hhgregg',
#   '90012',
#   'Los Angeles',
#   'CA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'chj787',
#   '5',
#   '7/1/2014',
#   'Much better screen than the samsung galaxy tablet'],
#  ['Sony TV 42 LED',
#   'TV',
#   '800',
#   'Frys',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Sony',
#   'No',
#   'fdyu323',
#   '4',
#   '2/1/2013',
#   'Sharp screen highly recommended'],
#  ['LG 65',
#   'TV',
#   '2250',
#   'Bestbuy',
#   '02110',
#   'Boston',
#   'MA',
#   'No',
#   'LG',
#   'No',
#   'spoi7124',
#   '5',
#   '5/1/2014',
#   'Exellent design and you can use the remote control to control the sound system as well'],
#  ['Dell XP 15',
#   'Laptop',
#   '1349',
#   'Hhgregg',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'hgjhg652',
#   '3',
#   '1/14/2014',
#   'noisy fan'],
#  ['HP Pavilion 15.6',
#   'Laptop',
#   '1399',
#   'Hhgregg',
#   '60603',
#   'Chicago',
#   'IL',
#   'Yes',
#   'HP',
#   'Yes',
#   'lkju763',
#   '2',
#   '1/15/2012',
#   'Bad monitor'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '2199',
#   'Bestbuy',
#   '94102',
#   'San Francisco',
#   'CA',
#   'No',
#   'Samsung',
#   'No',
#   'vwil639',
#   '5',
#   '8/21/2014',
#   'Perfect for watching basketball game'],
#  ['HP Pavilion 15.6 ',
#   'Laptop',
#   '599',
#   'Hhgregg',
#   '33130',
#   'Miami',
#   'FL',
#   'No',
#   'HP',
#   'No',
#   'jjer917',
#   '5',
#   '10/8/2014',
#   'good quality and performance'],
#  ['Galaxy S4',
#   'Smart Phone',
#   '499',
#   'Bestbuy',
#   '44114',
#   'Cleveland',
#   'OH',
#   'No',
#   'Samsung',
#   'No',
#   'xmm473',
#   '3',
#   '6/10/2012',
#   'overheats after 2 hours'],
#  ['Dell XP 13',
#   'Laptop',
#   '1349',
#   'Walmart',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'wywe5432',
#   '1',
#   '10/14/2014',
#   'screen goes blank when I start my HD games and the touch pad does not work always'],
#  ['iPhone 6',
#   'Smart Phone',
#   '299',
#   'Frys',
#   '30303',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Apple',
#   'No',
#   'akiy234',
#   '5',
#   '10/17/2014',
#   'Very thin design and easily fits in my pocket'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '2199',
#   'Bestbuy',
#   '02108',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'tfdr278',
#   '5',
#   '5/24/2014',
#   'Amazing screen and HD pictures on this TV'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Walmart',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'No',
#   'HTC',
#   'Yes',
#   'aopw447',
#   '5',
#   '11/21/2013',
#   'Alot of memory and you have the choice of to purchase the 16 GB to save all of your images'],
#  ['Surface 3',
#   'Tablet',
#   '499',
#   'Walmart',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Microsoft',
#   'No',
#   'kjru76',
#   '5',
#   '8/1/2014',
#   'Better screen than Samsung Galaxy tablet'],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '1349',
#   'Walmart',
#   '33129',
#   'Miami',
#   'FL',
#   'No',
#   'Lenevo',
#   'No',
#   'tom8723',
#   '3',
#   '8/18/2012',
#   'over priced'],
#  ['iPad Air',
#   'Tablet',
#   '499',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Apple',
#   'No',
#   'hgd987',
#   '5',
#   '4/1/2013',
#   'Battery is ok not bad as others complain about it'],
#  ['Samsung Galaxy Tab 4',
#   'Tablet',
#   '399',
#   'Walmart',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'sij392',
#   '5',
#   '2/26/2014',
#   'Good product for good price'],
#  ['Dell XP 13',
#   'Laptop',
#   '1099',
#   'Hhgregg',
#   '94158',
#   'San Francisco',
#   'CA',
#   'Yes',
#   'Dell',
#   'No',
#   'apae677',
#   '4',
#   '3/10/2015',
#   'good for gaming'],
#  ['HTC One',
#   'Smart Phone',
#   '299',
#   'Target',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'HTC',
#   'No',
#   'kjjasd67',
#   '2',
#   '10/13/2013',
#   'Bad battery'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1899',
#   'Target',
#   '30134',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'uys8219',
#   '1',
#   '9/24/2014',
#   'My sound system makes background noise when I connect it to the TV'],
#  ['Galaxy S4',
#   'Smart Phone',
#   '499',
#   'Bestbuy',
#   '44114',
#   'Cleveland',
#   'OH',
#   'No',
#   'Samsung',
#   'No',
#   'djh621',
#   '3',
#   '7/10/2013',
#   'overheats after 2 hours'],
#  ['Dell XP 13',
#   'Laptop',
#   '1200',
#   'Walmart',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'dur565',
#   '3',
#   '8/17/2014',
#   ' sound is not of a good quality'],
#  ['iPhone 6',
#   'Smart Phone',
#   '399',
#   'Target',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'Apple',
#   'No',
#   'bhru323',
#   '5',
#   '7/23/2014',
#   'Awesome display'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1900',
#   'Target',
#   '02108',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'jwsy537',
#   '4',
#   '2/15/2014',
#   'Really good for watching HD movies'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Walmart',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'No',
#   'HTC',
#   'Yes',
#   'rett891',
#   '1',
#   '6/21/2014',
#   'Battery dies after couple of hours of usage'],
#  ['Surface 3',
#   'Tablet',
#   '450',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'hsy5634',
#   '5',
#   '5/19/2014',
#   'really cool tablet and cheap compared to other devices'],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '1149',
#   'Hhgregg',
#   '33129',
#   'Miami',
#   'FL',
#   'Yes',
#   'Lenevo',
#   'Yes',
#   'sam3987',
#   '2',
#   '8/18/2014',
#   'Battery lasts only for 3 hours '],
#  ['iPad Air',
#   'Tablet',
#   '425',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Apple',
#   'No',
#   'lkiw736',
#   '5',
#   '8/13/2014',
#   'Does add  much load when you carry it in your bag'],
#  ['Samsung Galaxy Tab 4',
#   'Tablet',
#   '399',
#   'Hhgregg',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'ahwy345',
#   '2',
#   '7/16/2014',
#   'Some of my apps do not work on this tablet '],
#  ['Dell XP 13',
#   'Laptop',
#   '1150',
#   'Walmart',
#   '94158',
#   'San Francisco',
#   'CA',
#   'Yes',
#   'Dell',
#   'No',
#   'jak7810',
#   '5',
#   '3/10/2015',
#   'perfect for work and surfing the internet. Sharp screen and alot of horse power'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Target',
#   '30303',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'HTC',
#   'Yes',
#   'owy2907',
#   '5',
#   '9/13/2013',
#   'Good design and It is cheap compared to othe devices'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1899',
#   'Hhgregg',
#   '30134',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'fitn4937',
#   '5',
#   '5/23/2014',
#   'Excellent remote control design'],
#  ['Samsung TV 60 LED',
#   'TV',
#   '1100',
#   'Walmart',
#   '60585',
#   'Naperville',
#   'IL',
#   'No',
#   'Samsung',
#   'No',
#   'sam876',
#   '5',
#   '8/10/2014',
#   'works with my sound system perfectly'],
#  ['Surface 3',
#   'Tablet',
#   '399',
#   'Target',
#   '90012',
#   'Los Angeles',
#   'CA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'suw390',
#   '5',
#   '4/19/2014',
#   'The power of PC in a tablet'],
#  ['Sony TV 42 LED',
#   'TV',
#   '799',
#   'Target',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Sony',
#   'No',
#   'sawp973',
#   '3',
#   '8/1/2014',
#   'Samsung is better than this TV and cheaper. HDMI cable did not work porperly'],
#  ['LG 65',
#   'TV',
#   '2250',
#   'Bestbuy',
#   '02110',
#   'Boston',
#   'MA',
#   'No',
#   'LG',
#   'No',
#   'kwop360',
#   '5',
#   '4/29/2014',
#   'Works with all of the accessories that I have'],
#  ['Dell XP 15',
#   'Laptop',
#   '1899',
#   'Target',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'eric82',
#   '5',
#   '2/14/2014',
#   'Really good Battery'],
#  ['HP Pavilion 15.6',
#   'Laptop',
#   '1599',
#   'Hhgregg',
#   '60603',
#   'Chicago',
#   'IL',
#   'Yes',
#   'HP',
#   'NO',
#   'jwop026',
#   '5',
#   '12/15/2013',
#   'Exellent for gaming'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1799',
#   'Walmart',
#   '94102',
#   'San Francisco',
#   'CA',
#   'No',
#   'Samsung',
#   'No',
#   'dav286',
#   '2',
#   '8/21/2014',
#   'It did not connect to my bluetooth sound system'],
#  ['HP Pavilion 15.6 ',
#   'Laptop',
#   '599',
#   'Bestbuy',
#   '33130',
#   'Miami',
#   'FL',
#   'Yes',
#   'HP',
#   'Yes',
#   'nhy820',
#   '5',
#   '10/8/2014',
#   'I wish they had a better battery'],
#  ['Galaxy S4',
#   'Smart Phone',
#   '499',
#   'Frys',
#   '44114',
#   'Cleveland',
#   'OH',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'nwop390',
#   '4',
#   '9/19/2013',
#   'Power on and off button does not work always'],
#  ['Dell XP 13',
#   'Laptop',
#   '1349',
#   'Bestbuy',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'kwsf371',
#   '4',
#   '10/14/2014',
#   'Power cable is hort'],
#  ['iPhone 6',
#   'Smart Phone',
#   '399',
#   'Frys',
#   '30303',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Apple',
#   'No',
#   'bndo5430',
#   '2',
#   '8/10/2014',
#   'Did not connect to my headset'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '2099',
#   'Frys',
#   '02108',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'cdt2954',
#   '5',
#   '5/24/2014',
#   'Good TV and works with my entertainment system'],
#  ['HTC One',
#   'Smart Phone',
#   '99',
#   'Bestbuy',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'Yes',
#   'HTC',
#   'No',
#   'msyt259',
#   '5',
#   '9/21/2014',
#   'Good phone for cheap price'],
#  ['Surface 3',
#   'Tablet',
#   '425',
#   'Frys',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Microsoft',
#   'No',
#   'nwop316',
#   '2',
#   '8/1/2014',
#   'It freezes every couple of days'],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '999',
#   'Walmart',
#   '33129',
#   'Miami',
#   'FL',
#   'Yes',
#   'Lenevo',
#   'Yes',
#   'vdsu253',
#   '3',
#   '6/18/2013',
#   'Very noisy fan; it overheats after I play game on it for an hour'],
#  ['iPad Air',
#   'Tablet',
#   '299',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Apple',
#   'No',
#   'ruyt987',
#   '2',
#   '6/26/2014',
#   'Multitouch is not always accurate on the screen'],
#  ['Samsung Galaxy Tab 4',
#   'Tablet',
#   '599',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'mwiy389',
#   '5',
#   '2/26/2014',
#   'Superfast and good battery'],
#  ['Dell XP 13',
#   'Laptop',
#   '999',
#   'Frys',
#   '94158',
#   'San Francisco',
#   'CA',
#   'Yes',
#   'Dell',
#   'No',
#   'dggh556',
#   '5',
#   '11/10/2014',
#   'good for gaming'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Target',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'HTC',
#   'No',
#   'mnbw2487',
#   '2',
#   '3/13/2014',
#   'It overheats under heavy use and powers off on its own'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '2099',
#   'Walmart',
#   '30134',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Samsung',
#   'No',
#   'csu416',
#   '5',
#   '9/24/2014',
#   'Excellent for watching Netflix movies'],
#  ['Galaxy S4',
#   'Smart Phone',
#   '399',
#   'Walmart',
#   '44114',
#   'Cleveland',
#   'OH',
#   'No',
#   'Samsung',
#   'No',
#   'bsjk234',
#   '5',
#   '6/10/2014',
#   'Super fast but I wish it had a better battery'],
#  ['Dell XP 13',
#   'Laptop',
#   '999',
#   'Walmart',
#   '60616',
#   'Chicago',
#   'IL',
#   'Yes',
#   'Dell',
#   'No',
#   'vdi263',
#   '1',
#   '1/17/2015',
#   ' black and white screen only after 1 month of use'],
#  ['iPhone 6',
#   'Smart Phone',
#   '399',
#   'Target',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'Apple',
#   'No',
#   'dytr230',
#   '2',
#   '7/23/2014',
#   'It keeps freezing every now and then'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1900',
#   'Target',
#   '02108',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'ggt893',
#   '5',
#   '2/15/2014',
#   'Best TV I ever bought adn it works with all of the accessories'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Walmart',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'No',
#   'HTC',
#   'Yes',
#   'wett891',
#   '1',
#   '7/21/2014',
#   'After 2 months of use it overheated at some point and just died '],
#  ['Surface 3',
#   'Tablet',
#   '450',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'dem274',
#   '2',
#   '6/10/2014',
#   "Bad screen for HD gaming; don't buy it if you want to use it for gaming heavily"],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '1149',
#   'Hhgregg',
#   '33129',
#   'Miami',
#   'FL',
#   'Yes',
#   'Lenevo',
#   'Yes',
#   'lkwme367',
#   '5',
#   '8/18/2014',
#   'i checked out other reviews and Im pleased to say mine worked without any problem'],
#  ['iPad Air',
#   'Tablet',
#   '425',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Apple',
#   'No',
#   'ahm551',
#   '1',
#   '7/9/2014',
#   'It can not play all of my songs on this tablet and the speaker was dead'],
#  ['Samsung Galaxy Tab 4',
#   'Tablet',
#   '299',
#   'Hhgregg',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Samsung',
#   'No',
#   'kytr260',
#   '1',
#   '7/16/2014',
#   'this tablet overheats really fast and powers off on its own'],
#  ['Dell XP 13',
#   'Laptop',
#   '890',
#   'Target',
#   '94158',
#   'San Francisco',
#   'CA',
#   'Yes',
#   'Dell',
#   'No',
#   'mjak5610',
#   '1',
#   '2/1/2015',
#   'After one month of use it stopped working and it would not boot up again'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Bestbuy',
#   '30303',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'HTC',
#   'Yes',
#   'hwi377',
#   '1',
#   '9/13/2013',
#   'Overheated and died after 3 weeks of use'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1899',
#   'Walmart',
#   '30134',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'now786',
#   '4',
#   '2/15/2015',
#   'Remote control does not work beyond 3ft range'],
#  ['Samsung TV 60 LED',
#   'TV',
#   '1200',
#   'Bestbuy',
#   '60585',
#   'Naperville',
#   'IL',
#   'No',
#   'Samsung',
#   'No',
#   'suyw567',
#   '4',
#   '9/14/2014',
#   'Bluetooth is bad on this TV though'],
#  ['Surface 3',
#   'Tablet',
#   '399',
#   'Hhgregg',
#   '90012',
#   'Los Angeles',
#   'CA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'ffdd543',
#   '5',
#   '5/19/2014',
#   'bought it on sale'],
#  ['Sony TV 42 LED',
#   'TV',
#   '800',
#   'Frys',
#   '60616',
#   'Chicago',
#   'IL',
#   'Yes',
#   'Sony',
#   'Yes',
#   'nnft387',
#   '1',
#   '2/1/2013',
#   'My HDMI cable did not work for this TV'],
#  ['LG 65',
#   'TV',
#   '2250',
#   'Bestbuy',
#   '02110',
#   'Boston',
#   'MA',
#   'No',
#   'LG',
#   'No',
#   'mjki825',
#   '4',
#   '12/1/2014',
#   'The yellow color is not perfect on this TV'],
#  ['Dell XP 15',
#   'Laptop',
#   '1499',
#   'Hhgregg',
#   '60616',
#   'Chicago',
#   'IL',
#   'Yes',
#   'Dell',
#   'No',
#   'bvgt421',
#   '1',
#   '12/14/2014',
#   'Screen freezes when I start HD games on it'],
#  ['HP Pavilion 15.6',
#   'Laptop',
#   '1899',
#   'Hhgregg',
#   '60603',
#   'Chicago',
#   'IL',
#   'Yes',
#   'HP',
#   'Yes',
#   'mhty430',
#   '2',
#   '2/15/2015',
#   'Mouse pad is really slow'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '2199',
#   'Hhgregg',
#   '94102',
#   'San Francisco',
#   'CA',
#   'No',
#   'Samsung',
#   'No',
#   'diss395',
#   '1',
#   '8/21/2014',
#   'Remote control does not work beyond 3 ft range'],
#  ['HP Pavilion 15.6 ',
#   'Laptop',
#   '599',
#   'Hhgregg',
#   '33130',
#   'Miami',
#   'FL',
#   'Yes',
#   'HP',
#   'Yes',
#   'vsp4448',
#   '1',
#   '12/5/2014',
#   'Hard drive makes alot of noise'],
#  ['Galaxy S4',
#   'Smart Phone',
#   '499',
#   'Bestbuy',
#   '44114',
#   'Cleveland',
#   'OH',
#   'No',
#   'Samsung',
#   'No',
#   'jjwe395',
#   '1',
#   '8/10/2013',
#   'After an hour of heavy use it overheats'],
#  ['Dell XP 13',
#   'Laptop',
#   '1349',
#   'Bestbuy',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'jlae387',
#   '3',
#   '12/27/2014',
#   'Mouse pad is slow'],
#  ['iPhone 6',
#   'Smart Phone',
#   '299',
#   'Hhgregg',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'Apple',
#   'No',
#   'nasu547',
#   '2',
#   '12/10/2014',
#   'Needs longer battery'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '2199',
#   'Bestbuy',
#   '02108',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'mqrt498',
#   '4',
#   '3/24/2014',
#   'sharp screen and good for the family room'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Walmart',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'No',
#   'HTC',
#   'Yes',
#   'aopsawr452w447',
#   '4',
#   '8/21/2014',
#   'Does not work with my headset'],
#  ['Surface 3',
#   'Tablet',
#   '499',
#   'Walmart',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Microsoft',
#   'No',
#   'meay456',
#   '5',
#   '12/1/2014',
#   'Works without any problem with all of my bluetooth devices'],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '1349',
#   'Walmart',
#   '33129',
#   'Miami',
#   'FL',
#   'Yes',
#   'Lenevo',
#   'Yes',
#   'mist517',
#   '3',
#   '6/18/2014',
#   'over priced'],
#  ['iPad Air',
#   'Tablet',
#   '499',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Apple',
#   'No',
#   'dvn744',
#   '4',
#   '4/1/2015',
#   'Battery is really good but mouse pad is slow to respond sometimes'],
#  ['Samsung Galaxy Tab 4',
#   'Tablet',
#   '399',
#   'Walmart',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'alter458',
#   '1',
#   '2/29/2015',
#   'Does not work with my headset'],
#  ['Dell XP 13',
#   'Laptop',
#   '1099',
#   'Hhgregg',
#   '94158',
#   'San Francisco',
#   'CA',
#   'Yes',
#   'Dell',
#   'No',
#   'smht427',
#   '5',
#   '12/27/2014',
#   'Good design and battery lasts all day'],
#  ['HTC One',
#   'Smart Phone',
#   '299',
#   'Target',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'HTC',
#   'No',
#   'nwdt416',
#   '2',
#   '11/29/2014',
#   'Bad battery'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1899',
#   'Target',
#   '30134',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Samsung',
#   'No',
#   'redt437',
#   '1',
#   '12/20/2014',
#   'Bluetooth does not work with my sound bar '],
#  ['Galaxy S4',
#   'Smart Phone',
#   '499',
#   'Bestbuy',
#   '44114',
#   'Cleveland',
#   'OH',
#   'No',
#   'Samsung',
#   'No',
#   'emy524',
#   '5',
#   '5/25/2014',
#   'Easy to carry and battery lasts all day for me'],
#  ['Dell XP 13',
#   'Laptop',
#   '1200',
#   'Walmart',
#   '60616',
#   'Chicago',
#   'IL',
#   'No',
#   'Dell',
#   'No',
#   'tal384',
#   '1',
#   '11/25/2014',
#   ' Sound quality is really bad and screen goes blank often'],
#  ['iPhone 6',
#   'Smart Phone',
#   '399',
#   'Frys',
#   '30303',
#   'Atlanta',
#   'GA',
#   'No',
#   'Apple',
#   'No',
#   'sysw335',
#   '5',
#   '6/25/2014',
#   'Briliant design and easy to use'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1900',
#   'Target',
#   '02108',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'vid7765',
#   '1',
#   '10/25/2014',
#   'Really bad picture when I stream movies from Netflix'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Walmart',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'No',
#   'HTC',
#   'Yes',
#   'lan5432',
#   '5',
#   '6/21/2014',
#   'Exllent design and cheap price'],
#  ['Surface 3',
#   'Tablet',
#   '450',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'jin458',
#   '5',
#   '7/19/2014',
#   'really cool tablet and cheap compared to other devices'],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '1149',
#   'Hhgregg',
#   '33129',
#   'Miami',
#   'FL',
#   'Yes',
#   'Lenevo',
#   'Yes',
#   'rry5548',
#   '2',
#   '8/18/2014',
#   'Battery lasts only for 3 hours '],
#  ['iPad Air',
#   'Walmart',
#   '425',
#   'Target',
#   '02109',
#   'Boston',
#   'MA',
#   'Yes',
#   'Apple',
#   'No',
#   'yeln331',
#   '1',
#   '10/110/2013',
#   'Overheats in an hour when I use it  to play games'],
#  ['Samsung Galaxy Tab 4',
#   'Tablet',
#   '399',
#   'Bestbuy',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Samsung',
#   'No',
#   'many459',
#   '2',
#   '9/20/2014',
#   'Battery dies really fast'],
#  ['Dell XP 13',
#   'Laptop',
#   '1150',
#   'Walmart',
#   '94158',
#   'San Francisco',
#   'CA',
#   'Yes',
#   'Dell',
#   'No',
#   'edrd322',
#   '1',
#   '5/12/2014',
#   'Short power cord and screen goes blank quite often'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Frys',
#   '30303',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'HTC',
#   'Yes',
#   'tamn355',
#   '5',
#   '4/19/2014',
#   'It is cheap compared to other devices'],
#  ['Samsung TV 65 Curved',
#   'TV',
#   '1899',
#   'Hhgregg',
#   '30134',
#   'Atlanta',
#   'GA',
#   'Yes',
#   'Samsung',
#   'Yes',
#   'tak3783',
#   '1',
#   '9/17/2014',
#   'The romote control does not work'],
#  ['HTC One',
#   'Smart Phone',
#   '199',
#   'Walmart',
#   '90033',
#   'Los Angeles',
#   'CA',
#   'No',
#   'HTC',
#   'Yes',
#   'cara372',
#   '5',
#   '10/21/2014',
#   'Super fast and lot of memory'],
#  ['Surface 3',
#   'Tablet',
#   '499',
#   'Walmart',
#   '02109',
#   'Boston',
#   'MA',
#   'No',
#   'Microsoft',
#   'No',
#   'clrk773',
#   '1',
#   '10/28/2014',
#   'Swipe does not work all the time'],
#  ['Lenevo Y50 ',
#   'Laptop',
#   '1349',
#   'Walmart',
#   '33129',
#   'Miami',
#   'FL',
#   'No',
#   'Lenevo',
#   'No',
#   'chun2347',
#   '3',
#   '5/15/2013',
#   'The keyboard backlight is not bright enough'],
#  ['HP Pavilion 15.6 ',
#   'Laptop',
#   '599',
#   'Bestbuy',
#   '33130',
#   'Miami',
#   'FL',
#   'No',
#   'HP',
#   'No',
#   'laur277',
#   '3',
#   '7/8/2014',
#   'the mouse touch pad is bad']]

# %%
# 9. Add the Rows and  Columns we created 
# And that will be our hard-work for the Reviews Table

reviews_table = column_headers_for_reviews_table + rows_for_reviews_table

# %%
type(reviews_table)
# Out:
# list

# %%
reviews_table[:3]
# Out:
# [['ProductModelName',
#   'ProductCategory',
#   'ProductPrice',
#   'RetailerName',
#   'RetailerZipCode',
#   'RetailerCity',
#   'RetailerState',
#   'RetailerOnSale',
#   'ManufacturerName',
#   'ManufacturerRebate',
#   'ReviewUserId',
#   'ReviewRating',
#   'ReviewDate',
#   'ReviewText'],
#  ['Samsung TV 60 LED',
#   'TV',
#   '1200',
#   'Bestbuy',
#   '60585',
#   'Naperville',
#   'IL',
#   'No',
#   'Samsung',
#   'No',
#   'abc234',
#   '1',
#   '3/14/2013',
#   'Bluetooth did not work for my sound system'],
#  ['Surface 3',
#   'Tablet',
#   '399',
#   'Hhgregg',
#   '90012',
#   'Los Angeles',
#   'CA',
#   'Yes',
#   'Microsoft',
#   'No',
#   'chj787',
#   '5',
#   '7/1/2014',
#   'Much better screen than the samsung galaxy tablet']]

# %%
# 10. Write our Reviews Table (Remember it is LOL) into a CSV File

csvOutFile=open('CustomerReviews.csv','wt')	# this will be a text file

csvOutFile.write("\n".join(",".join(row) for row in reviews_table))

csvOutFile.close()

# %%
#11 Read the CSV file adn load it into DataFrame

custreview100=pd.read_csv('CustomerReviews.csv')

# %%
type(custreview100)
# Out:
# pandas.core.frame.DataFrame

# %%
custreview100.dtypes
# Out:
# ProductModelName      object
# ProductCategory       object
# ProductPrice           int64
# RetailerName          object
# RetailerZipCode        int64
# RetailerCity          object
# RetailerState         object
# RetailerOnSale        object
# ManufacturerName      object
# ManufacturerRebate    object
# ReviewUserId          object
# ReviewRating           int64
# ReviewDate            object
# ReviewText            object
# dtype: object

# %%
custreview100.head()
# Out:
#     ProductModelName ProductCategory  ProductPrice RetailerName  \
# 0  Samsung TV 60 LED              TV          1200      Bestbuy
# 1          Surface 3          Tablet           399      Hhgregg
# 2     Sony TV 42 LED              TV           800         Frys
# 3              LG 65              TV          2250      Bestbuy
# 4         Dell XP 15          Laptop          1349      Hhgregg
#
#    RetailerZipCode RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# 0            60585   Naperville            IL             No          Samsung
# 1            90012  Los Angeles            CA            Yes        Microsoft
# 2            60616      Chicago            IL             No             Sony
# 3             2110       Boston            MA             No               LG
# 4            60616      Chicago            IL             No             Dell
#
#   ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 0                 No       abc234             1  3/14/2013
# 1                 No       chj787             5   7/1/2014
# 2                 No      fdyu323             4   2/1/2013
# 3                 No     spoi7124             5   5/1/2014
# 4                 No     hgjhg652             3  1/14/2014
#
#                                           ReviewText
# 0         Bluetooth did not work for my sound system
# 1  Much better screen than the samsung galaxy tablet
# 2                    Sharp screen highly recommended
# 3  Exellent design and you can use the remote con...
# 4                                          noisy fan

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # +++++  Now lets execute different queries for our analysis  ++++++

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# ## Query 1: Print the list of all retailers along with the products and the rating

# %%
custreview100[['ProductModelName', 'RetailerName', 'ReviewRating']].head()
# Out:
#     ProductModelName RetailerName  ReviewRating
# 0  Samsung TV 60 LED      Bestbuy             1
# 1          Surface 3      Hhgregg             5
# 2     Sony TV 42 LED         Frys             4
# 3              LG 65      Bestbuy             5
# 4         Dell XP 15      Hhgregg             3

# %% [markdown]
# ## Query 2: Print a list  of reviews where rating greater than 3 - TWO WAYS TO DO IT - SEE BELOW

# %%
df4 = custreview100[custreview100['ReviewRating'] > 3]

# %%
df4[['ProductModelName', 'RetailerName', 'ReviewRating']].head()
# Out:
#        ProductModelName RetailerName  ReviewRating
# 1             Surface 3      Hhgregg             5
# 2        Sony TV 42 LED         Frys             4
# 3                 LG 65      Bestbuy             5
# 6  Samsung TV 65 Curved      Bestbuy             5
# 7     HP Pavilion 15.6       Hhgregg             5

# %%
custreview100[custreview100['ReviewRating'] > 3][['ProductModelName', 'RetailerName', 'ReviewRating']].head()
# Out:
#        ProductModelName RetailerName  ReviewRating
# 1             Surface 3      Hhgregg             5
# 2        Sony TV 42 LED         Frys             4
# 3                 LG 65      Bestbuy             5
# 6  Samsung TV 65 Curved      Bestbuy             5
# 7     HP Pavilion 15.6       Hhgregg             5

# %% [markdown]
# # Query 3: Get a list of products that got review rating 5 and price more than thousand

# %%
custreview100[(custreview100['ReviewRating'] == 5) & (custreview100['ProductPrice'] > 1000)].head()
# Out:
#         ProductModelName ProductCategory  ProductPrice RetailerName  \
# 3                  LG 65              TV          2250      Bestbuy
# 6   Samsung TV 65 Curved              TV          2199      Bestbuy
# 11  Samsung TV 65 Curved              TV          2199      Bestbuy
# 29            Dell XP 13          Laptop          1150      Walmart
# 31  Samsung TV 65 Curved              TV          1899      Hhgregg
#
#     RetailerZipCode   RetailerCity RetailerState RetailerOnSale  \
# 3              2110         Boston            MA             No
# 6             94102  San Francisco            CA             No
# 11             2108         Boston            MA             No
# 29            94158  San Francisco            CA            Yes
# 31            30134        Atlanta            GA            Yes
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 3                LG                 No     spoi7124             5   5/1/2014
# 6           Samsung                 No      vwil639             5  8/21/2014
# 11          Samsung                 No      tfdr278             5  5/24/2014
# 29             Dell                 No      jak7810             5  3/10/2015
# 31          Samsung                Yes     fitn4937             5  5/23/2014
#
#                                            ReviewText
# 3   Exellent design and you can use the remote con...
# 6                Perfect for watching basketball game
# 11          Amazing screen and HD pictures on this TV
# 29  perfect for work and surfing the internet. Sha...
# 31                    Excellent remote control design

# %%
custreview100.head()
# Out:
#     ProductModelName ProductCategory  ProductPrice RetailerName  \
# 0  Samsung TV 60 LED              TV          1200      Bestbuy
# 1          Surface 3          Tablet           399      Hhgregg
# 2     Sony TV 42 LED              TV           800         Frys
# 3              LG 65              TV          2250      Bestbuy
# 4         Dell XP 15          Laptop          1349      Hhgregg
#
#    RetailerZipCode RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# 0            60585   Naperville            IL             No          Samsung
# 1            90012  Los Angeles            CA            Yes        Microsoft
# 2            60616      Chicago            IL             No             Sony
# 3             2110       Boston            MA             No               LG
# 4            60616      Chicago            IL             No             Dell
#
#   ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 0                 No       abc234             1  3/14/2013
# 1                 No       chj787             5   7/1/2014
# 2                 No      fdyu323             4   2/1/2013
# 3                 No     spoi7124             5   5/1/2014
# 4                 No     hgjhg652             3  1/14/2014
#
#                                           ReviewText
# 0         Bluetooth did not work for my sound system
# 1  Much better screen than the samsung galaxy tablet
# 2                    Sharp screen highly recommended
# 3  Exellent design and you can use the remote con...
# 4                                          noisy fan

# %% [markdown]
# # Query 4: How many products reviewed for every retailer?

# %%
custreview100.RetailerName.value_counts()
# Out:
# Walmart    26
# Target     25
# Hhgregg    20
# Bestbuy    19
# Frys       10
# Name: RetailerName, dtype: int64

# %% [markdown]
# # Query 5: How many reviews for every product?

# %%
custreview100.ProductModelName.value_counts()
# Out:
# Samsung TV 65 Curved    15
# HTC One                 13
# Dell XP 13              12
# Surface 3               10
# Lenevo Y50               7
# Galaxy S4                6
# iPad Air                 6
# Samsung Galaxy Tab 4     6
# iPhone 6                 6
# HP Pavilion 15.6         4
# Dell XP 15               3
# Samsung TV 60 LED        3
# Sony TV 42 LED           3
# LG 65                    3
# HP Pavilion 15.6         3
# Name: ProductModelName, dtype: int64

# %% [markdown]
# # Query 6: How many reviews for every product category?

# %%
custreview100.ProductCategory .value_counts()
# Out:
# Laptop         29
# Smart Phone    25
# TV             24
# Tablet         21
# Walmart         1
# Name: ProductCategory, dtype: int64

# %% [markdown]
# # Query 7: Get the list of reviews for shoppers in Chicago

# %%
ChicagoShoppers=custreview100[custreview100.RetailerCity=='Chicago']

# %%
ChicagoShoppers.head()
# Out:
#     ProductModelName ProductCategory  ProductPrice RetailerName  \
# 2     Sony TV 42 LED              TV           800         Frys
# 4         Dell XP 15          Laptop          1349      Hhgregg
# 5   HP Pavilion 15.6          Laptop          1399      Hhgregg
# 9         Dell XP 13          Laptop          1349      Walmart
# 21        Dell XP 13          Laptop          1200      Walmart
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 2             60616      Chicago            IL             No
# 4             60616      Chicago            IL             No
# 5             60603      Chicago            IL            Yes
# 9             60616      Chicago            IL             No
# 21            60616      Chicago            IL             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# 2              Sony                 No      fdyu323             4    2/1/2013
# 4              Dell                 No     hgjhg652             3   1/14/2014
# 5                HP                Yes      lkju763             2   1/15/2012
# 9              Dell                 No     wywe5432             1  10/14/2014
# 21             Dell                 No       dur565             3   8/17/2014
#
#                                            ReviewText
# 2                     Sharp screen highly recommended
# 4                                           noisy fan
# 5                                         Bad monitor
# 9   screen goes blank when I start my HD games and...
# 21                     sound is not of a good quality

# %% [markdown]
# # Query 8: Set the index of the ChicagoShoopers to be RetailerName

# %%
ChicagoShoppers=ChicagoShoppers.set_index('RetailerName')

# %%
ChicagoShoppers.head()
# Out:
#               ProductModelName ProductCategory  ProductPrice  RetailerZipCode  \
# RetailerName
# Frys            Sony TV 42 LED              TV           800            60616
# Hhgregg             Dell XP 15          Laptop          1349            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1399            60603
# Walmart             Dell XP 13          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1200            60616
#
#              RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# RetailerName
# Frys              Chicago            IL             No             Sony
# Hhgregg           Chicago            IL             No             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
#
#              ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# RetailerName
# Frys                         No      fdyu323             4    2/1/2013
# Hhgregg                      No     hgjhg652             3   1/14/2014
# Hhgregg                     Yes      lkju763             2   1/15/2012
# Walmart                      No     wywe5432             1  10/14/2014
# Walmart                      No       dur565             3   8/17/2014
#
#                                                      ReviewText
# RetailerName
# Frys                            Sharp screen highly recommended
# Hhgregg                                               noisy fan
# Hhgregg                                             Bad monitor
# Walmart       screen goes blank when I start my HD games and...
# Walmart                          sound is not of a good quality

# %% [markdown]
# # Query 9: Sort the dataframe based on the row-label index -- that is the retailer name

# %%
ChicagoShoppers=ChicagoShoppers.sort_index()

# %%
ChicagoShoppers
# Out:
#               ProductModelName ProductCategory  ProductPrice  RetailerZipCode  \
# RetailerName
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Hhgregg             Dell XP 15          Laptop          1349            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1399            60603
# Hhgregg       HP Pavilion 15.6          Laptop          1599            60603
# Hhgregg             Dell XP 15          Laptop          1499            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1899            60603
# Target          Sony TV 42 LED              TV           799            60616
# Target              Dell XP 15          Laptop          1899            60616
# Walmart             Dell XP 13          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop           999            60616
# Walmart             Dell XP 13          Laptop          1200            60616
#
#              RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# RetailerName
# Bestbuy           Chicago            IL             No             Dell
# Bestbuy           Chicago            IL             No             Dell
# Frys              Chicago            IL             No             Sony
# Frys              Chicago            IL            Yes             Sony
# Hhgregg           Chicago            IL             No             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Target            Chicago            IL             No             Sony
# Target            Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL            Yes             Dell
# Walmart           Chicago            IL             No             Dell
#
#              ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# RetailerName
# Bestbuy                      No      kwsf371             4  10/14/2014
# Bestbuy                      No      jlae387             3  12/27/2014
# Frys                         No      fdyu323             4    2/1/2013
# Frys                        Yes      nnft387             1    2/1/2013
# Hhgregg                      No     hgjhg652             3   1/14/2014
# Hhgregg                     Yes      lkju763             2   1/15/2012
# Hhgregg                      NO      jwop026             5  12/15/2013
# Hhgregg                      No      bvgt421             1  12/14/2014
# Hhgregg                     Yes      mhty430             2   2/15/2015
# Target                       No      sawp973             3    8/1/2014
# Target                       No       eric82             5   2/14/2014
# Walmart                      No     wywe5432             1  10/14/2014
# Walmart                      No       dur565             3   8/17/2014
# Walmart                      No       vdi263             1   1/17/2015
# Walmart                      No       tal384             1  11/25/2014
#
#                                                      ReviewText
# RetailerName
# Bestbuy                                     Power cable is hort
# Bestbuy                                       Mouse pad is slow
# Frys                            Sharp screen highly recommended
# Frys                     My HDMI cable did not work for this TV
# Hhgregg                                               noisy fan
# Hhgregg                                             Bad monitor
# Hhgregg                                     Exellent for gaming
# Hhgregg              Screen freezes when I start HD games on it
# Hhgregg                                Mouse pad is really slow
# Target        Samsung is better than this TV and cheaper. HD...
# Target                                      Really good Battery
# Walmart       screen goes blank when I start my HD games and...
# Walmart                          sound is not of a good quality
# Walmart        black and white screen only after 1 month of use
# Walmart        Sound quality is really bad and screen goes b...

# %% [markdown]
# # Query 10: Sorting based on column values using sort_values

# %%
ChicagoShoppers.sort_values(by='ProductPrice', ascending=False)
# Out:
#               ProductModelName ProductCategory  ProductPrice  RetailerZipCode  \
# RetailerName
# Hhgregg       HP Pavilion 15.6          Laptop          1899            60603
# Target              Dell XP 15          Laptop          1899            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1599            60603
# Hhgregg             Dell XP 15          Laptop          1499            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1399            60603
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Hhgregg             Dell XP 15          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop           999            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Target          Sony TV 42 LED              TV           799            60616
#
#              RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# RetailerName
# Hhgregg           Chicago            IL            Yes               HP
# Target            Chicago            IL             No             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Bestbuy           Chicago            IL             No             Dell
# Bestbuy           Chicago            IL             No             Dell
# Hhgregg           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL            Yes             Dell
# Frys              Chicago            IL             No             Sony
# Frys              Chicago            IL            Yes             Sony
# Target            Chicago            IL             No             Sony
#
#              ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# RetailerName
# Hhgregg                     Yes      mhty430             2   2/15/2015
# Target                       No       eric82             5   2/14/2014
# Hhgregg                      NO      jwop026             5  12/15/2013
# Hhgregg                      No      bvgt421             1  12/14/2014
# Hhgregg                     Yes      lkju763             2   1/15/2012
# Bestbuy                      No      kwsf371             4  10/14/2014
# Bestbuy                      No      jlae387             3  12/27/2014
# Hhgregg                      No     hgjhg652             3   1/14/2014
# Walmart                      No     wywe5432             1  10/14/2014
# Walmart                      No       dur565             3   8/17/2014
# Walmart                      No       tal384             1  11/25/2014
# Walmart                      No       vdi263             1   1/17/2015
# Frys                         No      fdyu323             4    2/1/2013
# Frys                        Yes      nnft387             1    2/1/2013
# Target                       No      sawp973             3    8/1/2014
#
#                                                      ReviewText
# RetailerName
# Hhgregg                                Mouse pad is really slow
# Target                                      Really good Battery
# Hhgregg                                     Exellent for gaming
# Hhgregg              Screen freezes when I start HD games on it
# Hhgregg                                             Bad monitor
# Bestbuy                                     Power cable is hort
# Bestbuy                                       Mouse pad is slow
# Hhgregg                                               noisy fan
# Walmart       screen goes blank when I start my HD games and...
# Walmart                          sound is not of a good quality
# Walmart        Sound quality is really bad and screen goes b...
# Walmart        black and white screen only after 1 month of use
# Frys                            Sharp screen highly recommended
# Frys                     My HDMI cable did not work for this TV
# Target        Samsung is better than this TV and cheaper. HD...

# %% [markdown]
# ## sort_values doesn't change the original copy of the dataframe object. If you want the results for later processing, store them in a new datframe object

# %%
ChicagoShoppers
# Out:
#               ProductModelName ProductCategory  ProductPrice  RetailerZipCode  \
# RetailerName
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Hhgregg             Dell XP 15          Laptop          1349            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1399            60603
# Hhgregg       HP Pavilion 15.6          Laptop          1599            60603
# Hhgregg             Dell XP 15          Laptop          1499            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1899            60603
# Target          Sony TV 42 LED              TV           799            60616
# Target              Dell XP 15          Laptop          1899            60616
# Walmart             Dell XP 13          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop           999            60616
# Walmart             Dell XP 13          Laptop          1200            60616
#
#              RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# RetailerName
# Bestbuy           Chicago            IL             No             Dell
# Bestbuy           Chicago            IL             No             Dell
# Frys              Chicago            IL             No             Sony
# Frys              Chicago            IL            Yes             Sony
# Hhgregg           Chicago            IL             No             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Target            Chicago            IL             No             Sony
# Target            Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL            Yes             Dell
# Walmart           Chicago            IL             No             Dell
#
#              ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# RetailerName
# Bestbuy                      No      kwsf371             4  10/14/2014
# Bestbuy                      No      jlae387             3  12/27/2014
# Frys                         No      fdyu323             4    2/1/2013
# Frys                        Yes      nnft387             1    2/1/2013
# Hhgregg                      No     hgjhg652             3   1/14/2014
# Hhgregg                     Yes      lkju763             2   1/15/2012
# Hhgregg                      NO      jwop026             5  12/15/2013
# Hhgregg                      No      bvgt421             1  12/14/2014
# Hhgregg                     Yes      mhty430             2   2/15/2015
# Target                       No      sawp973             3    8/1/2014
# Target                       No       eric82             5   2/14/2014
# Walmart                      No     wywe5432             1  10/14/2014
# Walmart                      No       dur565             3   8/17/2014
# Walmart                      No       vdi263             1   1/17/2015
# Walmart                      No       tal384             1  11/25/2014
#
#                                                      ReviewText
# RetailerName
# Bestbuy                                     Power cable is hort
# Bestbuy                                       Mouse pad is slow
# Frys                            Sharp screen highly recommended
# Frys                     My HDMI cable did not work for this TV
# Hhgregg                                               noisy fan
# Hhgregg                                             Bad monitor
# Hhgregg                                     Exellent for gaming
# Hhgregg              Screen freezes when I start HD games on it
# Hhgregg                                Mouse pad is really slow
# Target        Samsung is better than this TV and cheaper. HD...
# Target                                      Really good Battery
# Walmart       screen goes blank when I start my HD games and...
# Walmart                          sound is not of a good quality
# Walmart        black and white screen only after 1 month of use
# Walmart        Sound quality is really bad and screen goes b...

# %% [markdown]
# # Query 11: Sort Column values using sort_values method to return and store results in a Dataframe object

# %%
ChicagoShoppersSortedPrice=ChicagoShoppers.sort_values(by='ProductPrice', ascending=False)

# %%
ChicagoShoppersSortedPrice
# Out:
#               ProductModelName ProductCategory  ProductPrice  RetailerZipCode  \
# RetailerName
# Hhgregg       HP Pavilion 15.6          Laptop          1899            60603
# Target              Dell XP 15          Laptop          1899            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1599            60603
# Hhgregg             Dell XP 15          Laptop          1499            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1399            60603
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Hhgregg             Dell XP 15          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop           999            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Target          Sony TV 42 LED              TV           799            60616
#
#              RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# RetailerName
# Hhgregg           Chicago            IL            Yes               HP
# Target            Chicago            IL             No             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Bestbuy           Chicago            IL             No             Dell
# Bestbuy           Chicago            IL             No             Dell
# Hhgregg           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL            Yes             Dell
# Frys              Chicago            IL             No             Sony
# Frys              Chicago            IL            Yes             Sony
# Target            Chicago            IL             No             Sony
#
#              ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# RetailerName
# Hhgregg                     Yes      mhty430             2   2/15/2015
# Target                       No       eric82             5   2/14/2014
# Hhgregg                      NO      jwop026             5  12/15/2013
# Hhgregg                      No      bvgt421             1  12/14/2014
# Hhgregg                     Yes      lkju763             2   1/15/2012
# Bestbuy                      No      kwsf371             4  10/14/2014
# Bestbuy                      No      jlae387             3  12/27/2014
# Hhgregg                      No     hgjhg652             3   1/14/2014
# Walmart                      No     wywe5432             1  10/14/2014
# Walmart                      No       dur565             3   8/17/2014
# Walmart                      No       tal384             1  11/25/2014
# Walmart                      No       vdi263             1   1/17/2015
# Frys                         No      fdyu323             4    2/1/2013
# Frys                        Yes      nnft387             1    2/1/2013
# Target                       No      sawp973             3    8/1/2014
#
#                                                      ReviewText
# RetailerName
# Hhgregg                                Mouse pad is really slow
# Target                                      Really good Battery
# Hhgregg                                     Exellent for gaming
# Hhgregg              Screen freezes when I start HD games on it
# Hhgregg                                             Bad monitor
# Bestbuy                                     Power cable is hort
# Bestbuy                                       Mouse pad is slow
# Hhgregg                                               noisy fan
# Walmart       screen goes blank when I start my HD games and...
# Walmart                          sound is not of a good quality
# Walmart        Sound quality is really bad and screen goes b...
# Walmart        black and white screen only after 1 month of use
# Frys                            Sharp screen highly recommended
# Frys                     My HDMI cable did not work for this TV
# Target        Samsung is better than this TV and cheaper. HD...

# %% [markdown]
# # Query 12: Sort based on two column values. We are sorting based on product prices then based on manufacturer name

# %%
ChicagoShoppersSortedPriceAndManufacturer=ChicagoShoppers.sort_values(ascending=[False, True], 
                                                                     by=['ProductPrice', 'ManufacturerName'])

# %%
ChicagoShoppersSortedPriceAndManufacturer
# Out:
#               ProductModelName ProductCategory  ProductPrice  RetailerZipCode  \
# RetailerName
# Target              Dell XP 15          Laptop          1899            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1899            60603
# Hhgregg       HP Pavilion 15.6          Laptop          1599            60603
# Hhgregg             Dell XP 15          Laptop          1499            60616
# Hhgregg       HP Pavilion 15.6          Laptop          1399            60603
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Bestbuy             Dell XP 13          Laptop          1349            60616
# Hhgregg             Dell XP 15          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1349            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop          1200            60616
# Walmart             Dell XP 13          Laptop           999            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Frys            Sony TV 42 LED              TV           800            60616
# Target          Sony TV 42 LED              TV           799            60616
#
#              RetailerCity RetailerState RetailerOnSale ManufacturerName  \
# RetailerName
# Target            Chicago            IL             No             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes               HP
# Hhgregg           Chicago            IL            Yes             Dell
# Hhgregg           Chicago            IL            Yes               HP
# Bestbuy           Chicago            IL             No             Dell
# Bestbuy           Chicago            IL             No             Dell
# Hhgregg           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL             No             Dell
# Walmart           Chicago            IL            Yes             Dell
# Frys              Chicago            IL             No             Sony
# Frys              Chicago            IL            Yes             Sony
# Target            Chicago            IL             No             Sony
#
#              ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# RetailerName
# Target                       No       eric82             5   2/14/2014
# Hhgregg                     Yes      mhty430             2   2/15/2015
# Hhgregg                      NO      jwop026             5  12/15/2013
# Hhgregg                      No      bvgt421             1  12/14/2014
# Hhgregg                     Yes      lkju763             2   1/15/2012
# Bestbuy                      No      kwsf371             4  10/14/2014
# Bestbuy                      No      jlae387             3  12/27/2014
# Hhgregg                      No     hgjhg652             3   1/14/2014
# Walmart                      No     wywe5432             1  10/14/2014
# Walmart                      No       dur565             3   8/17/2014
# Walmart                      No       tal384             1  11/25/2014
# Walmart                      No       vdi263             1   1/17/2015
# Frys                         No      fdyu323             4    2/1/2013
# Frys                        Yes      nnft387             1    2/1/2013
# Target                       No      sawp973             3    8/1/2014
#
#                                                      ReviewText
# RetailerName
# Target                                      Really good Battery
# Hhgregg                                Mouse pad is really slow
# Hhgregg                                     Exellent for gaming
# Hhgregg              Screen freezes when I start HD games on it
# Hhgregg                                             Bad monitor
# Bestbuy                                     Power cable is hort
# Bestbuy                                       Mouse pad is slow
# Hhgregg                                               noisy fan
# Walmart       screen goes blank when I start my HD games and...
# Walmart                          sound is not of a good quality
# Walmart        Sound quality is really bad and screen goes b...
# Walmart        black and white screen only after 1 month of use
# Frys                            Sharp screen highly recommended
# Frys                     My HDMI cable did not work for this TV
# Target        Samsung is better than this TV and cheaper. HD...

# %% [markdown]
# ## Set the index to be ProductModelName

# %%
Top10LikedItemsInChicago=ChicagoShoppers.set_index('ProductModelName')
Top10LikedItemsInChicago.head()
# Out:
#                  ProductCategory  ProductPrice  RetailerZipCode RetailerCity  \
# ProductModelName
# Dell XP 13                Laptop          1349            60616      Chicago
# Dell XP 13                Laptop          1349            60616      Chicago
# Sony TV 42 LED                TV           800            60616      Chicago
# Sony TV 42 LED                TV           800            60616      Chicago
# Dell XP 15                Laptop          1349            60616      Chicago
#
#                  RetailerState RetailerOnSale ManufacturerName  \
# ProductModelName
# Dell XP 13                  IL             No             Dell
# Dell XP 13                  IL             No             Dell
# Sony TV 42 LED              IL             No             Sony
# Sony TV 42 LED              IL            Yes             Sony
# Dell XP 15                  IL             No             Dell
#
#                  ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# ProductModelName
# Dell XP 13                       No      kwsf371             4  10/14/2014
# Dell XP 13                       No      jlae387             3  12/27/2014
# Sony TV 42 LED                   No      fdyu323             4    2/1/2013
# Sony TV 42 LED                  Yes      nnft387             1    2/1/2013
# Dell XP 15                       No     hgjhg652             3   1/14/2014
#
#                                               ReviewText
# ProductModelName
# Dell XP 13                           Power cable is hort
# Dell XP 13                             Mouse pad is slow
# Sony TV 42 LED           Sharp screen highly recommended
# Sony TV 42 LED    My HDMI cable did not work for this TV
# Dell XP 15                                     noisy fan

# %% [markdown]
# # Query 13: Get the top 10 list of items liked in Chicago

# %%
Top10LikedItemsInChicago=Top10LikedItemsInChicago.sort_values(by='ReviewRating', ascending=False)[:10]

# %%
Top10LikedItemsInChicago
# Out:
#                  ProductCategory  ProductPrice  RetailerZipCode RetailerCity  \
# ProductModelName
# HP Pavilion 15.6          Laptop          1599            60603      Chicago
# Dell XP 15                Laptop          1899            60616      Chicago
# Dell XP 13                Laptop          1349            60616      Chicago
# Sony TV 42 LED                TV           800            60616      Chicago
# Dell XP 13                Laptop          1349            60616      Chicago
# Dell XP 15                Laptop          1349            60616      Chicago
# Sony TV 42 LED                TV           799            60616      Chicago
# Dell XP 13                Laptop          1200            60616      Chicago
# HP Pavilion 15.6          Laptop          1399            60603      Chicago
# HP Pavilion 15.6          Laptop          1899            60603      Chicago
#
#                  RetailerState RetailerOnSale ManufacturerName  \
# ProductModelName
# HP Pavilion 15.6            IL            Yes               HP
# Dell XP 15                  IL             No             Dell
# Dell XP 13                  IL             No             Dell
# Sony TV 42 LED              IL             No             Sony
# Dell XP 13                  IL             No             Dell
# Dell XP 15                  IL             No             Dell
# Sony TV 42 LED              IL             No             Sony
# Dell XP 13                  IL             No             Dell
# HP Pavilion 15.6            IL            Yes               HP
# HP Pavilion 15.6            IL            Yes               HP
#
#                  ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# ProductModelName
# HP Pavilion 15.6                 NO      jwop026             5  12/15/2013
# Dell XP 15                       No       eric82             5   2/14/2014
# Dell XP 13                       No      kwsf371             4  10/14/2014
# Sony TV 42 LED                   No      fdyu323             4    2/1/2013
# Dell XP 13                       No      jlae387             3  12/27/2014
# Dell XP 15                       No     hgjhg652             3   1/14/2014
# Sony TV 42 LED                   No      sawp973             3    8/1/2014
# Dell XP 13                       No       dur565             3   8/17/2014
# HP Pavilion 15.6                Yes      lkju763             2   1/15/2012
# HP Pavilion 15.6                Yes      mhty430             2   2/15/2015
#
#                                                          ReviewText
# ProductModelName
# HP Pavilion 15.6                                Exellent for gaming
# Dell XP 15                                      Really good Battery
# Dell XP 13                                      Power cable is hort
# Sony TV 42 LED                      Sharp screen highly recommended
# Dell XP 13                                        Mouse pad is slow
# Dell XP 15                                                noisy fan
# Sony TV 42 LED    Samsung is better than this TV and cheaper. HD...
# Dell XP 13                           sound is not of a good quality
# HP Pavilion 15.6                                        Bad monitor
# HP Pavilion 15.6                           Mouse pad is really slow

# %% [markdown]
# # Query 14: groupby returns a group of dataframe objects indexed based on akey you specify more or less dictionary-like

# %%
ItemsReviewedByCity=custreview100.groupby('RetailerCity')

# %%
type(ItemsReviewedByCity)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
for key, group in ItemsReviewedByCity:
    print (key)
    print (group)
# Out:
# Atlanta
#         ProductModelName ProductCategory  ProductPrice RetailerName  \
# 10              iPhone 6     Smart Phone           299         Frys
# 18               HTC One     Smart Phone           299       Target
# 19  Samsung TV 65 Curved              TV          1899       Target
# 22              iPhone 6     Smart Phone           399       Target
# 30               HTC One     Smart Phone           199       Target
# 31  Samsung TV 65 Curved              TV          1899      Hhgregg
# 42              iPhone 6     Smart Phone           399         Frys
# 50               HTC One     Smart Phone           199       Target
# 51  Samsung TV 65 Curved              TV          2099      Walmart
# 54              iPhone 6     Smart Phone           399       Target
# 62               HTC One     Smart Phone           199      Bestbuy
# 63  Samsung TV 65 Curved              TV          1899      Walmart
# 74              iPhone 6     Smart Phone           299      Hhgregg
# 82               HTC One     Smart Phone           299       Target
# 83  Samsung TV 65 Curved              TV          1899       Target
# 86              iPhone 6     Smart Phone           399         Frys
# 94               HTC One     Smart Phone           199         Frys
# 95  Samsung TV 65 Curved              TV          1899      Hhgregg
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 10            30303      Atlanta            GA            Yes
# 18            30303      Atlanta            GA             No
# 19            30134      Atlanta            GA            Yes
# 22            30303      Atlanta            GA             No
# 30            30303      Atlanta            GA            Yes
# 31            30134      Atlanta            GA            Yes
# 42            30303      Atlanta            GA            Yes
# 50            30303      Atlanta            GA             No
# 51            30134      Atlanta            GA            Yes
# 54            30303      Atlanta            GA             No
# 62            30303      Atlanta            GA            Yes
# 63            30134      Atlanta            GA            Yes
# 74            30303      Atlanta            GA             No
# 82            30303      Atlanta            GA             No
# 83            30134      Atlanta            GA            Yes
# 86            30303      Atlanta            GA             No
# 94            30303      Atlanta            GA            Yes
# 95            30134      Atlanta            GA            Yes
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# 10            Apple                 No      akiy234             5  10/17/2014
# 18              HTC                 No     kjjasd67             2  10/13/2013
# 19          Samsung                Yes      uys8219             1   9/24/2014
# 22            Apple                 No      bhru323             5   7/23/2014
# 30              HTC                Yes      owy2907             5   9/13/2013
# 31          Samsung                Yes     fitn4937             5   5/23/2014
# 42            Apple                 No     bndo5430             2   8/10/2014
# 50              HTC                 No     mnbw2487             2   3/13/2014
# 51          Samsung                 No       csu416             5   9/24/2014
# 54            Apple                 No      dytr230             2   7/23/2014
# 62              HTC                Yes       hwi377             1   9/13/2013
# 63          Samsung                Yes       now786             4   2/15/2015
# 74            Apple                 No      nasu547             2  12/10/2014
# 82              HTC                 No      nwdt416             2  11/29/2014
# 83          Samsung                 No      redt437             1  12/20/2014
# 86            Apple                 No      sysw335             5   6/25/2014
# 94              HTC                Yes      tamn355             5   4/19/2014
# 95          Samsung                Yes      tak3783             1   9/17/2014
#
#                                            ReviewText
# 10      Very thin design and easily fits in my pocket
# 18                                        Bad battery
# 19  My sound system makes background noise when I ...
# 22                                    Awesome display
# 30  Good design and It is cheap compared to othe d...
# 31                    Excellent remote control design
# 42                      Did not connect to my headset
# 50  It overheats under heavy use and powers off on...
# 51              Excellent for watching Netflix movies
# 54               It keeps freezing every now and then
# 62           Overheated and died after 3 weeks of use
# 63      Remote control does not work beyond 3ft range
# 74                               Needs longer battery
# 82                                        Bad battery
# 83         Bluetooth does not work with my sound bar
# 86                    Briliant design and easy to use
# 94              It is cheap compared to other devices
# 95                   The romote control does not work
# Boston
#         ProductModelName ProductCategory  ProductPrice RetailerName  \
# 3                  LG 65              TV          2250      Bestbuy
# 11  Samsung TV 65 Curved              TV          2199      Bestbuy
# 13             Surface 3          Tablet           499      Walmart
# 15              iPad Air          Tablet           499       Target
# 16  Samsung Galaxy Tab 4          Tablet           399      Walmart
# 23  Samsung TV 65 Curved              TV          1900       Target
# 25             Surface 3          Tablet           450       Target
# 27              iPad Air          Tablet           425       Target
# 28  Samsung Galaxy Tab 4          Tablet           399      Hhgregg
# 35                 LG 65              TV          2250      Bestbuy
# 43  Samsung TV 65 Curved              TV          2099         Frys
# 45             Surface 3          Tablet           425         Frys
# 47              iPad Air          Tablet           299       Target
# 48  Samsung Galaxy Tab 4          Tablet           599       Target
# 55  Samsung TV 65 Curved              TV          1900       Target
# 57             Surface 3          Tablet           450       Target
# 59              iPad Air          Tablet           425       Target
# 60  Samsung Galaxy Tab 4          Tablet           299      Hhgregg
# 67                 LG 65              TV          2250      Bestbuy
# 75  Samsung TV 65 Curved              TV          2199      Bestbuy
# 77             Surface 3          Tablet           499      Walmart
# 79              iPad Air          Tablet           499       Target
# 80  Samsung Galaxy Tab 4          Tablet           399      Walmart
# 87  Samsung TV 65 Curved              TV          1900       Target
# 89             Surface 3          Tablet           450       Target
# 91              iPad Air         Walmart           425       Target
# 92  Samsung Galaxy Tab 4          Tablet           399      Bestbuy
# 97             Surface 3          Tablet           499      Walmart
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 3              2110       Boston            MA             No
# 11             2108       Boston            MA             No
# 13             2109       Boston            MA             No
# 15             2109       Boston            MA             No
# 16             2109       Boston            MA             No
# 23             2108       Boston            MA             No
# 25             2109       Boston            MA            Yes
# 27             2109       Boston            MA            Yes
# 28             2109       Boston            MA            Yes
# 35             2110       Boston            MA             No
# 43             2108       Boston            MA             No
# 45             2109       Boston            MA             No
# 47             2109       Boston            MA            Yes
# 48             2109       Boston            MA            Yes
# 55             2108       Boston            MA             No
# 57             2109       Boston            MA            Yes
# 59             2109       Boston            MA            Yes
# 60             2109       Boston            MA            Yes
# 67             2110       Boston            MA             No
# 75             2108       Boston            MA             No
# 77             2109       Boston            MA             No
# 79             2109       Boston            MA             No
# 80             2109       Boston            MA             No
# 87             2108       Boston            MA             No
# 89             2109       Boston            MA            Yes
# 91             2109       Boston            MA            Yes
# 92             2109       Boston            MA             No
# 97             2109       Boston            MA             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating  \
# 3                LG                 No     spoi7124             5
# 11          Samsung                 No      tfdr278             5
# 13        Microsoft                 No       kjru76             5
# 15            Apple                 No       hgd987             5
# 16          Samsung                 No       sij392             5
# 23          Samsung                 No      jwsy537             4
# 25        Microsoft                 No      hsy5634             5
# 27            Apple                 No      lkiw736             5
# 28          Samsung                Yes      ahwy345             2
# 35               LG                 No      kwop360             5
# 43          Samsung                 No      cdt2954             5
# 45        Microsoft                 No      nwop316             2
# 47            Apple                 No      ruyt987             2
# 48          Samsung                Yes      mwiy389             5
# 55          Samsung                 No       ggt893             5
# 57        Microsoft                 No       dem274             2
# 59            Apple                 No       ahm551             1
# 60          Samsung                 No      kytr260             1
# 67               LG                 No      mjki825             4
# 75          Samsung                 No      mqrt498             4
# 77        Microsoft                 No      meay456             5
# 79            Apple                 No       dvn744             4
# 80          Samsung                 No     alter458             1
# 87          Samsung                 No      vid7765             1
# 89        Microsoft                 No       jin458             5
# 91            Apple                 No      yeln331             1
# 92          Samsung                 No      many459             2
# 97        Microsoft                 No      clrk773             1
#
#      ReviewDate                                         ReviewText
# 3      5/1/2014  Exellent design and you can use the remote con...
# 11    5/24/2014          Amazing screen and HD pictures on this TV
# 13     8/1/2014           Better screen than Samsung Galaxy tablet
# 15     4/1/2013  Battery is ok not bad as others complain about it
# 16    2/26/2014                        Good product for good price
# 23    2/15/2014                 Really good for watching HD movies
# 25    5/19/2014  really cool tablet and cheap compared to other...
# 27    8/13/2014  Does add  much load when you carry it in your bag
# 28    7/16/2014        Some of my apps do not work on this tablet
# 35    4/29/2014      Works with all of the accessories that I have
# 43    5/24/2014     Good TV and works with my entertainment system
# 45     8/1/2014                    It freezes every couple of days
# 47    6/26/2014    Multitouch is not always accurate on the screen
# 48    2/26/2014                         Superfast and good battery
# 55    2/15/2014  Best TV I ever bought adn it works with all of...
# 57    6/10/2014  Bad screen for HD gaming; don't buy it if you ...
# 59     7/9/2014  It can not play all of my songs on this tablet...
# 60    7/16/2014  this tablet overheats really fast and powers o...
# 67    12/1/2014         The yellow color is not perfect on this TV
# 75    3/24/2014          sharp screen and good for the family room
# 77    12/1/2014  Works without any problem with all of my bluet...
# 79     4/1/2015  Battery is really good but mouse pad is slow t...
# 80    2/29/2015                      Does not work with my headset
# 87   10/25/2014  Really bad picture when I stream movies from N...
# 89    7/19/2014  really cool tablet and cheap compared to other...
# 91  10/110/2013  Overheats in an hour when I use it  to play games
# 92    9/20/2014                           Battery dies really fast
# 97   10/28/2014                   Swipe does not work all the time
# Chicago
#     ProductModelName ProductCategory  ProductPrice RetailerName  \
# 2     Sony TV 42 LED              TV           800         Frys
# 4         Dell XP 15          Laptop          1349      Hhgregg
# 5   HP Pavilion 15.6          Laptop          1399      Hhgregg
# 9         Dell XP 13          Laptop          1349      Walmart
# 21        Dell XP 13          Laptop          1200      Walmart
# 34    Sony TV 42 LED              TV           799       Target
# 36        Dell XP 15          Laptop          1899       Target
# 37  HP Pavilion 15.6          Laptop          1599      Hhgregg
# 41        Dell XP 13          Laptop          1349      Bestbuy
# 53        Dell XP 13          Laptop           999      Walmart
# 66    Sony TV 42 LED              TV           800         Frys
# 68        Dell XP 15          Laptop          1499      Hhgregg
# 69  HP Pavilion 15.6          Laptop          1899      Hhgregg
# 73        Dell XP 13          Laptop          1349      Bestbuy
# 85        Dell XP 13          Laptop          1200      Walmart
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 2             60616      Chicago            IL             No
# 4             60616      Chicago            IL             No
# 5             60603      Chicago            IL            Yes
# 9             60616      Chicago            IL             No
# 21            60616      Chicago            IL             No
# 34            60616      Chicago            IL             No
# 36            60616      Chicago            IL             No
# 37            60603      Chicago            IL            Yes
# 41            60616      Chicago            IL             No
# 53            60616      Chicago            IL            Yes
# 66            60616      Chicago            IL            Yes
# 68            60616      Chicago            IL            Yes
# 69            60603      Chicago            IL            Yes
# 73            60616      Chicago            IL             No
# 85            60616      Chicago            IL             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# 2              Sony                 No      fdyu323             4    2/1/2013
# 4              Dell                 No     hgjhg652             3   1/14/2014
# 5                HP                Yes      lkju763             2   1/15/2012
# 9              Dell                 No     wywe5432             1  10/14/2014
# 21             Dell                 No       dur565             3   8/17/2014
# 34             Sony                 No      sawp973             3    8/1/2014
# 36             Dell                 No       eric82             5   2/14/2014
# 37               HP                 NO      jwop026             5  12/15/2013
# 41             Dell                 No      kwsf371             4  10/14/2014
# 53             Dell                 No       vdi263             1   1/17/2015
# 66             Sony                Yes      nnft387             1    2/1/2013
# 68             Dell                 No      bvgt421             1  12/14/2014
# 69               HP                Yes      mhty430             2   2/15/2015
# 73             Dell                 No      jlae387             3  12/27/2014
# 85             Dell                 No       tal384             1  11/25/2014
#
#                                            ReviewText
# 2                     Sharp screen highly recommended
# 4                                           noisy fan
# 5                                         Bad monitor
# 9   screen goes blank when I start my HD games and...
# 21                     sound is not of a good quality
# 34  Samsung is better than this TV and cheaper. HD...
# 36                                Really good Battery
# 37                                Exellent for gaming
# 41                                Power cable is hort
# 53   black and white screen only after 1 month of use
# 66             My HDMI cable did not work for this TV
# 68         Screen freezes when I start HD games on it
# 69                           Mouse pad is really slow
# 73                                  Mouse pad is slow
# 85   Sound quality is really bad and screen goes b...
# Cleveland
#    ProductModelName ProductCategory  ProductPrice RetailerName  \
# 8         Galaxy S4     Smart Phone           499      Bestbuy
# 20        Galaxy S4     Smart Phone           499      Bestbuy
# 40        Galaxy S4     Smart Phone           499         Frys
# 52        Galaxy S4     Smart Phone           399      Walmart
# 72        Galaxy S4     Smart Phone           499      Bestbuy
# 84        Galaxy S4     Smart Phone           499      Bestbuy
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 8             44114    Cleveland            OH             No
# 20            44114    Cleveland            OH             No
# 40            44114    Cleveland            OH            Yes
# 52            44114    Cleveland            OH             No
# 72            44114    Cleveland            OH             No
# 84            44114    Cleveland            OH             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 8           Samsung                 No       xmm473             3  6/10/2012
# 20          Samsung                 No       djh621             3  7/10/2013
# 40          Samsung                Yes      nwop390             4  9/19/2013
# 52          Samsung                 No      bsjk234             5  6/10/2014
# 72          Samsung                 No      jjwe395             1  8/10/2013
# 84          Samsung                 No       emy524             5  5/25/2014
#
#                                         ReviewText
# 8                          overheats after 2 hours
# 20                         overheats after 2 hours
# 40    Power on and off button does not work always
# 52   Super fast but I wish it had a better battery
# 72         After an hour of heavy use it overheats
# 84  Easy to carry and battery lasts all day for me
# Los Angeles
#    ProductModelName ProductCategory  ProductPrice RetailerName  \
# 1         Surface 3          Tablet           399      Hhgregg
# 12          HTC One     Smart Phone           199      Walmart
# 24          HTC One     Smart Phone           199      Walmart
# 33        Surface 3          Tablet           399       Target
# 44          HTC One     Smart Phone            99      Bestbuy
# 56          HTC One     Smart Phone           199      Walmart
# 65        Surface 3          Tablet           399      Hhgregg
# 76          HTC One     Smart Phone           199      Walmart
# 88          HTC One     Smart Phone           199      Walmart
# 96          HTC One     Smart Phone           199      Walmart
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 1             90012  Los Angeles            CA            Yes
# 12            90033  Los Angeles            CA             No
# 24            90033  Los Angeles            CA             No
# 33            90012  Los Angeles            CA            Yes
# 44            90033  Los Angeles            CA            Yes
# 56            90033  Los Angeles            CA             No
# 65            90012  Los Angeles            CA            Yes
# 76            90033  Los Angeles            CA             No
# 88            90033  Los Angeles            CA             No
# 96            90033  Los Angeles            CA             No
#
#    ManufacturerName ManufacturerRebate    ReviewUserId  ReviewRating  \
# 1         Microsoft                 No          chj787             5
# 12              HTC                Yes         aopw447             5
# 24              HTC                Yes         rett891             1
# 33        Microsoft                 No          suw390             5
# 44              HTC                 No         msyt259             5
# 56              HTC                Yes         wett891             1
# 65        Microsoft                 No         ffdd543             5
# 76              HTC                Yes  aopsawr452w447             4
# 88              HTC                Yes         lan5432             5
# 96              HTC                Yes         cara372             5
#
#     ReviewDate                                         ReviewText
# 1     7/1/2014  Much better screen than the samsung galaxy tablet
# 12  11/21/2013  Alot of memory and you have the choice of to p...
# 24   6/21/2014        Battery dies after couple of hours of usage
# 33   4/19/2014                        The power of PC in a tablet
# 44   9/21/2014                         Good phone for cheap price
# 56   7/21/2014  After 2 months of use it overheated at some po...
# 65   5/19/2014                                  bought it on sale
# 76   8/21/2014                      Does not work with my headset
# 88   6/21/2014                     Exllent design and cheap price
# 96  10/21/2014                       Super fast and lot of memory
# Miami
#      ProductModelName ProductCategory  ProductPrice RetailerName  \
# 7   HP Pavilion 15.6           Laptop           599      Hhgregg
# 14        Lenevo Y50           Laptop          1349      Walmart
# 26        Lenevo Y50           Laptop          1149      Hhgregg
# 39  HP Pavilion 15.6           Laptop           599      Bestbuy
# 46        Lenevo Y50           Laptop           999      Walmart
# 58        Lenevo Y50           Laptop          1149      Hhgregg
# 71  HP Pavilion 15.6           Laptop           599      Hhgregg
# 78        Lenevo Y50           Laptop          1349      Walmart
# 90        Lenevo Y50           Laptop          1149      Hhgregg
# 98        Lenevo Y50           Laptop          1349      Walmart
# 99  HP Pavilion 15.6           Laptop           599      Bestbuy
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 7             33130        Miami            FL             No
# 14            33129        Miami            FL             No
# 26            33129        Miami            FL            Yes
# 39            33130        Miami            FL            Yes
# 46            33129        Miami            FL            Yes
# 58            33129        Miami            FL            Yes
# 71            33130        Miami            FL            Yes
# 78            33129        Miami            FL            Yes
# 90            33129        Miami            FL            Yes
# 98            33129        Miami            FL             No
# 99            33130        Miami            FL             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 7                HP                 No      jjer917             5  10/8/2014
# 14           Lenevo                 No      tom8723             3  8/18/2012
# 26           Lenevo                Yes      sam3987             2  8/18/2014
# 39               HP                Yes       nhy820             5  10/8/2014
# 46           Lenevo                Yes      vdsu253             3  6/18/2013
# 58           Lenevo                Yes     lkwme367             5  8/18/2014
# 71               HP                Yes      vsp4448             1  12/5/2014
# 78           Lenevo                Yes      mist517             3  6/18/2014
# 90           Lenevo                Yes      rry5548             2  8/18/2014
# 98           Lenevo                 No     chun2347             3  5/15/2013
# 99               HP                 No      laur277             3   7/8/2014
#
#                                            ReviewText
# 7                        good quality and performance
# 14                                        over priced
# 26                    Battery lasts only for 3 hours
# 39                   I wish they had a better battery
# 46  Very noisy fan; it overheats after I play game...
# 58  i checked out other reviews and Im pleased to ...
# 71                     Hard drive makes alot of noise
# 78                                        over priced
# 90                    Battery lasts only for 3 hours
# 98        The keyboard backlight is not bright enough
# 99                         the mouse touch pad is bad
# Naperville
#      ProductModelName ProductCategory  ProductPrice RetailerName  \
# 0   Samsung TV 60 LED              TV          1200      Bestbuy
# 32  Samsung TV 60 LED              TV          1100      Walmart
# 64  Samsung TV 60 LED              TV          1200      Bestbuy
#
#     RetailerZipCode RetailerCity RetailerState RetailerOnSale  \
# 0             60585   Naperville            IL             No
# 32            60585   Naperville            IL             No
# 64            60585   Naperville            IL             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 0           Samsung                 No       abc234             1  3/14/2013
# 32          Samsung                 No       sam876             5  8/10/2014
# 64          Samsung                 No      suyw567             4  9/14/2014
#
#                                     ReviewText
# 0   Bluetooth did not work for my sound system
# 32        works with my sound system perfectly
# 64          Bluetooth is bad on this TV though
# San Francisco
#         ProductModelName ProductCategory  ProductPrice RetailerName  \
# 6   Samsung TV 65 Curved              TV          2199      Bestbuy
# 17            Dell XP 13          Laptop          1099      Hhgregg
# 29            Dell XP 13          Laptop          1150      Walmart
# 38  Samsung TV 65 Curved              TV          1799      Walmart
# 49            Dell XP 13          Laptop           999         Frys
# 61            Dell XP 13          Laptop           890       Target
# 70  Samsung TV 65 Curved              TV          2199      Hhgregg
# 81            Dell XP 13          Laptop          1099      Hhgregg
# 93            Dell XP 13          Laptop          1150      Walmart
#
#     RetailerZipCode   RetailerCity RetailerState RetailerOnSale  \
# 6             94102  San Francisco            CA             No
# 17            94158  San Francisco            CA            Yes
# 29            94158  San Francisco            CA            Yes
# 38            94102  San Francisco            CA             No
# 49            94158  San Francisco            CA            Yes
# 61            94158  San Francisco            CA            Yes
# 70            94102  San Francisco            CA             No
# 81            94158  San Francisco            CA            Yes
# 93            94158  San Francisco            CA            Yes
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# 6           Samsung                 No      vwil639             5   8/21/2014
# 17             Dell                 No      apae677             4   3/10/2015
# 29             Dell                 No      jak7810             5   3/10/2015
# 38          Samsung                 No       dav286             2   8/21/2014
# 49             Dell                 No      dggh556             5  11/10/2014
# 61             Dell                 No     mjak5610             1    2/1/2015
# 70          Samsung                 No      diss395             1   8/21/2014
# 81             Dell                 No      smht427             5  12/27/2014
# 93             Dell                 No      edrd322             1   5/12/2014
#
#                                            ReviewText
# 6                Perfect for watching basketball game
# 17                                    good for gaming
# 29  perfect for work and surfing the internet. Sha...
# 38    It did not connect to my bluetooth sound system
# 49                                    good for gaming
# 61  After one month of use it stopped working and ...
# 70     Remote control does not work beyond 3 ft range
# 81              Good design and battery lasts all day
# 93  Short power cord and screen goes blank quite o...

# %% [markdown]
# # Query 15: Find highest price product reviewed/sold in every city

# %%
#generator comprehension for retrieving highest product sold by city
gl = (group.sort_values(by='ProductPrice', ascending=False)[:1] for rtc, group in ItemsReviewedByCity )

# %%
gl
# Out:
# <generator object <genexpr> at 0x000001BA7553EF68>

# %%
topProductsByCity = pd.DataFrame()

# %%
for line in gl:
    topProductsByCity = topProductsByCity.append(line)

# %%
topProductsByCity
# Out:
#         ProductModelName ProductCategory  ProductPrice RetailerName  \
# 51  Samsung TV 65 Curved              TV          2099      Walmart
# 3                  LG 65              TV          2250      Bestbuy
# 36            Dell XP 15          Laptop          1899       Target
# 8              Galaxy S4     Smart Phone           499      Bestbuy
# 1              Surface 3          Tablet           399      Hhgregg
# 14           Lenevo Y50           Laptop          1349      Walmart
# 0      Samsung TV 60 LED              TV          1200      Bestbuy
# 6   Samsung TV 65 Curved              TV          2199      Bestbuy
#
#     RetailerZipCode   RetailerCity RetailerState RetailerOnSale  \
# 51            30134        Atlanta            GA            Yes
# 3              2110         Boston            MA             No
# 36            60616        Chicago            IL             No
# 8             44114      Cleveland            OH             No
# 1             90012    Los Angeles            CA            Yes
# 14            33129          Miami            FL             No
# 0             60585     Naperville            IL             No
# 6             94102  San Francisco            CA             No
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating ReviewDate  \
# 51          Samsung                 No       csu416             5  9/24/2014
# 3                LG                 No     spoi7124             5   5/1/2014
# 36             Dell                 No       eric82             5  2/14/2014
# 8           Samsung                 No       xmm473             3  6/10/2012
# 1         Microsoft                 No       chj787             5   7/1/2014
# 14           Lenevo                 No      tom8723             3  8/18/2012
# 0           Samsung                 No       abc234             1  3/14/2013
# 6           Samsung                 No      vwil639             5  8/21/2014
#
#                                            ReviewText
# 51              Excellent for watching Netflix movies
# 3   Exellent design and you can use the remote con...
# 36                                Really good Battery
# 8                             overheats after 2 hours
# 1   Much better screen than the samsung galaxy tablet
# 14                                        over priced
# 0          Bluetooth did not work for my sound system
# 6                Perfect for watching basketball game

# %% [markdown]
# # Query 16: Plot median product prices per city

# %%
# %matplotlib inline 

ItemsReviewedByCity['ProductPrice'].median().plot()

# %% [markdown]
# # Query 17: Get the top 5 list of liked products for every city

# %%
#generator  for retrieving top 5 products liked by city
gTopRating5 = (group.sort_values(by='ReviewRating', ascending=False)[:5] for rtc, group in ItemsReviewedByCity )

# %%
topLikedProductsByCity = pd.DataFrame()

# %%
for line in gTopRating5 :
    topLikedProductsByCity = topLikedProductsByCity.append(line)

# %%
topLikedProductsByCity
# Out:
#         ProductModelName ProductCategory  ProductPrice RetailerName  \
# 10              iPhone 6     Smart Phone           299         Frys
# 94               HTC One     Smart Phone           199         Frys
# 22              iPhone 6     Smart Phone           399       Target
# 30               HTC One     Smart Phone           199       Target
# 31  Samsung TV 65 Curved              TV          1899      Hhgregg
# 3                  LG 65              TV          2250      Bestbuy
# 35                 LG 65              TV          2250      Bestbuy
# 89             Surface 3          Tablet           450       Target
# 77             Surface 3          Tablet           499      Walmart
# 11  Samsung TV 65 Curved              TV          2199      Bestbuy
# 36            Dell XP 15          Laptop          1899       Target
# 37      HP Pavilion 15.6          Laptop          1599      Hhgregg
# 2         Sony TV 42 LED              TV           800         Frys
# 41            Dell XP 13          Laptop          1349      Bestbuy
# 4             Dell XP 15          Laptop          1349      Hhgregg
# 52             Galaxy S4     Smart Phone           399      Walmart
# 84             Galaxy S4     Smart Phone           499      Bestbuy
# 40             Galaxy S4     Smart Phone           499         Frys
# 8              Galaxy S4     Smart Phone           499      Bestbuy
# 20             Galaxy S4     Smart Phone           499      Bestbuy
# 1              Surface 3          Tablet           399      Hhgregg
# 12               HTC One     Smart Phone           199      Walmart
# 33             Surface 3          Tablet           399       Target
# 44               HTC One     Smart Phone            99      Bestbuy
# 65             Surface 3          Tablet           399      Hhgregg
# 7      HP Pavilion 15.6           Laptop           599      Hhgregg
# 39     HP Pavilion 15.6           Laptop           599      Bestbuy
# 58           Lenevo Y50           Laptop          1149      Hhgregg
# 14           Lenevo Y50           Laptop          1349      Walmart
# 46           Lenevo Y50           Laptop           999      Walmart
# 32     Samsung TV 60 LED              TV          1100      Walmart
# 64     Samsung TV 60 LED              TV          1200      Bestbuy
# 0      Samsung TV 60 LED              TV          1200      Bestbuy
# 6   Samsung TV 65 Curved              TV          2199      Bestbuy
# 29            Dell XP 13          Laptop          1150      Walmart
# 49            Dell XP 13          Laptop           999         Frys
# 81            Dell XP 13          Laptop          1099      Hhgregg
# 17            Dell XP 13          Laptop          1099      Hhgregg
#
#     RetailerZipCode   RetailerCity RetailerState RetailerOnSale  \
# 10            30303        Atlanta            GA            Yes
# 94            30303        Atlanta            GA            Yes
# 22            30303        Atlanta            GA             No
# 30            30303        Atlanta            GA            Yes
# 31            30134        Atlanta            GA            Yes
# 3              2110         Boston            MA             No
# 35             2110         Boston            MA             No
# 89             2109         Boston            MA            Yes
# 77             2109         Boston            MA             No
# 11             2108         Boston            MA             No
# 36            60616        Chicago            IL             No
# 37            60603        Chicago            IL            Yes
# 2             60616        Chicago            IL             No
# 41            60616        Chicago            IL             No
# 4             60616        Chicago            IL             No
# 52            44114      Cleveland            OH             No
# 84            44114      Cleveland            OH             No
# 40            44114      Cleveland            OH            Yes
# 8             44114      Cleveland            OH             No
# 20            44114      Cleveland            OH             No
# 1             90012    Los Angeles            CA            Yes
# 12            90033    Los Angeles            CA             No
# 33            90012    Los Angeles            CA            Yes
# 44            90033    Los Angeles            CA            Yes
# 65            90012    Los Angeles            CA            Yes
# 7             33130          Miami            FL             No
# 39            33130          Miami            FL            Yes
# 58            33129          Miami            FL            Yes
# 14            33129          Miami            FL             No
# 46            33129          Miami            FL            Yes
# 32            60585     Naperville            IL             No
# 64            60585     Naperville            IL             No
# 0             60585     Naperville            IL             No
# 6             94102  San Francisco            CA             No
# 29            94158  San Francisco            CA            Yes
# 49            94158  San Francisco            CA            Yes
# 81            94158  San Francisco            CA            Yes
# 17            94158  San Francisco            CA            Yes
#
#    ManufacturerName ManufacturerRebate ReviewUserId  ReviewRating  ReviewDate  \
# 10            Apple                 No      akiy234             5  10/17/2014
# 94              HTC                Yes      tamn355             5   4/19/2014
# 22            Apple                 No      bhru323             5   7/23/2014
# 30              HTC                Yes      owy2907             5   9/13/2013
# 31          Samsung                Yes     fitn4937             5   5/23/2014
# 3                LG                 No     spoi7124             5    5/1/2014
# 35               LG                 No      kwop360             5   4/29/2014
# 89        Microsoft                 No       jin458             5   7/19/2014
# 77        Microsoft                 No      meay456             5   12/1/2014
# 11          Samsung                 No      tfdr278             5   5/24/2014
# 36             Dell                 No       eric82             5   2/14/2014
# 37               HP                 NO      jwop026             5  12/15/2013
# 2              Sony                 No      fdyu323             4    2/1/2013
# 41             Dell                 No      kwsf371             4  10/14/2014
# 4              Dell                 No     hgjhg652             3   1/14/2014
# 52          Samsung                 No      bsjk234             5   6/10/2014
# 84          Samsung                 No       emy524             5   5/25/2014
# 40          Samsung                Yes      nwop390             4   9/19/2013
# 8           Samsung                 No       xmm473             3   6/10/2012
# 20          Samsung                 No       djh621             3   7/10/2013
# 1         Microsoft                 No       chj787             5    7/1/2014
# 12              HTC                Yes      aopw447             5  11/21/2013
# 33        Microsoft                 No       suw390             5   4/19/2014
# 44              HTC                 No      msyt259             5   9/21/2014
# 65        Microsoft                 No      ffdd543             5   5/19/2014
# 7                HP                 No      jjer917             5   10/8/2014
# 39               HP                Yes       nhy820             5   10/8/2014
# 58           Lenevo                Yes     lkwme367             5   8/18/2014
# 14           Lenevo                 No      tom8723             3   8/18/2012
# 46           Lenevo                Yes      vdsu253             3   6/18/2013
# 32          Samsung                 No       sam876             5   8/10/2014
# 64          Samsung                 No      suyw567             4   9/14/2014
# 0           Samsung                 No       abc234             1   3/14/2013
# 6           Samsung                 No      vwil639             5   8/21/2014
# 29             Dell                 No      jak7810             5   3/10/2015
# 49             Dell                 No      dggh556             5  11/10/2014
# 81             Dell                 No      smht427             5  12/27/2014
# 17             Dell                 No      apae677             4   3/10/2015
#
#                                            ReviewText
# 10      Very thin design and easily fits in my pocket
# 94              It is cheap compared to other devices
# 22                                    Awesome display
# 30  Good design and It is cheap compared to othe d...
# 31                    Excellent remote control design
# 3   Exellent design and you can use the remote con...
# 35      Works with all of the accessories that I have
# 89  really cool tablet and cheap compared to other...
# 77  Works without any problem with all of my bluet...
# 11          Amazing screen and HD pictures on this TV
# 36                                Really good Battery
# 37                                Exellent for gaming
# 2                     Sharp screen highly recommended
# 41                                Power cable is hort
# 4                                           noisy fan
# 52      Super fast but I wish it had a better battery
# 84     Easy to carry and battery lasts all day for me
# 40       Power on and off button does not work always
# 8                             overheats after 2 hours
# 20                            overheats after 2 hours
# 1   Much better screen than the samsung galaxy tablet
# 12  Alot of memory and you have the choice of to p...
# 33                        The power of PC in a tablet
# 44                         Good phone for cheap price
# 65                                  bought it on sale
# 7                        good quality and performance
# 39                   I wish they had a better battery
# 58  i checked out other reviews and Im pleased to ...
# 14                                        over priced
# 46  Very noisy fan; it overheats after I play game...
# 32               works with my sound system perfectly
# 64                 Bluetooth is bad on this TV though
# 0          Bluetooth did not work for my sound system
# 6                Perfect for watching basketball game
# 29  perfect for work and surfing the internet. Sha...
# 49                                    good for gaming
# 81              Good design and battery lasts all day
# 17                                    good for gaming

# %% [markdown]
# # Query 18: Get top 5 list of most liked and expensive products sorted by retailer name for every city

# %%
#generator  for retrieving top 5 products most expensive and liked by city
gTop5LikedExpensive = (group.sort_values(ascending=[False, False, True], 
                                        by=['ReviewRating', 'ProductPrice', 'RetailerName'])[:5] 
                       for rtc, group in ItemsReviewedByCity )

# %%
top5LikedExpensiveProductsByCity = pd.DataFrame()

# %%
for line in gTop5LikedExpensive :
    top5LikedExpensiveProductsByCity = top5LikedExpensiveProductsByCity.append(line)

# %%
top5LikedExpensiveProductsByCity[['RetailerCity', 'RetailerName', 'ProductModelName', 'ProductPrice', 'ReviewRating']]
# Out:
#      RetailerCity RetailerName      ProductModelName  ProductPrice  \
# 51        Atlanta      Walmart  Samsung TV 65 Curved          2099
# 31        Atlanta      Hhgregg  Samsung TV 65 Curved          1899
# 86        Atlanta         Frys              iPhone 6           399
# 22        Atlanta       Target              iPhone 6           399
# 10        Atlanta         Frys              iPhone 6           299
# 3          Boston      Bestbuy                 LG 65          2250
# 35         Boston      Bestbuy                 LG 65          2250
# 11         Boston      Bestbuy  Samsung TV 65 Curved          2199
# 43         Boston         Frys  Samsung TV 65 Curved          2099
# 55         Boston       Target  Samsung TV 65 Curved          1900
# 36        Chicago       Target            Dell XP 15          1899
# 37        Chicago      Hhgregg      HP Pavilion 15.6          1599
# 41        Chicago      Bestbuy            Dell XP 13          1349
# 2         Chicago         Frys        Sony TV 42 LED           800
# 73        Chicago      Bestbuy            Dell XP 13          1349
# 84      Cleveland      Bestbuy             Galaxy S4           499
# 52      Cleveland      Walmart             Galaxy S4           399
# 40      Cleveland         Frys             Galaxy S4           499
# 8       Cleveland      Bestbuy             Galaxy S4           499
# 20      Cleveland      Bestbuy             Galaxy S4           499
# 1     Los Angeles      Hhgregg             Surface 3           399
# 65    Los Angeles      Hhgregg             Surface 3           399
# 33    Los Angeles       Target             Surface 3           399
# 12    Los Angeles      Walmart               HTC One           199
# 88    Los Angeles      Walmart               HTC One           199
# 58          Miami      Hhgregg           Lenevo Y50           1149
# 39          Miami      Bestbuy     HP Pavilion 15.6            599
# 7           Miami      Hhgregg     HP Pavilion 15.6            599
# 14          Miami      Walmart           Lenevo Y50           1349
# 78          Miami      Walmart           Lenevo Y50           1349
# 32     Naperville      Walmart     Samsung TV 60 LED          1100
# 64     Naperville      Bestbuy     Samsung TV 60 LED          1200
# 0      Naperville      Bestbuy     Samsung TV 60 LED          1200
# 6   San Francisco      Bestbuy  Samsung TV 65 Curved          2199
# 29  San Francisco      Walmart            Dell XP 13          1150
# 81  San Francisco      Hhgregg            Dell XP 13          1099
# 49  San Francisco         Frys            Dell XP 13           999
# 17  San Francisco      Hhgregg            Dell XP 13          1099
#
#     ReviewRating
# 51             5
# 31             5
# 86             5
# 22             5
# 10             5
# 3              5
# 35             5
# 11             5
# 43             5
# 55             5
# 36             5
# 37             5
# 41             4
# 2              4
# 73             3
# 84             5
# 52             5
# 40             4
# 8              3
# 20             3
# 1              5
# 65             5
# 33             5
# 12             5
# 88             5
# 58             5
# 39             5
# 7              5
# 14             3
# 78             3
# 32             5
# 64             4
# 0              1
# 6              5
# 29             5
# 81             5
# 49             5
# 17             4

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Write Python code for the following requirements (ONE-CELL-FOR-EVERY-REQUIREMENT):

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # +++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Requirement #1:

# %% [raw]
# Get the top 5 list of most Disliked products sorted by retailer name for every city

# %% [markdown]
# # Requirement #2:

# %% [raw]
# Get the top 5 list of cheapest products sorted by retailer name for every city

# %% [markdown]
# # Requirement #3:

# %% [raw]
# Get the total number of products reviewed and got Rating 5 in Every City

# %% [markdown]
# # Requirement #4:

# %% [raw]
# Get the top 2 list of zip-codes where highest number of products got review rating 5

# %% [markdown]
# # Requirement #5:

# %% [raw]
# which  City got the most liked (rating >2) products sorted by product names

# %% [markdown]
# # Bonus Requirement (20% bonus/extra points for Assignment #3):

# %% [raw]
# Create unstacked BarChart for the reviews in every city group
